# %%
import sys
sys.path.append('..')

import numpy as np
import pandas as pd
from pathlib import Path

from src.models.association_rules import AssociationRuleModel
from src.models.collaborative_filtering import CollaborativeFilteringModel
from src.models.hybrid_recommender import HybridRecommender

# FORCE_RETRAIN_AR=True

# %%
# ====================== Config ======================
MODELS_DIR = Path("../models")
MODELS_DIR.mkdir(parents=True, exist_ok=True)

AR_PATH = MODELS_DIR / "association_rule_model.pkl"
CF_PATH = MODELS_DIR / "cf_model_als.pkl"

# 默认不重训：优先加载已有checkpoint
RETRAIN_AR_IF_MISSING = True
RETRAIN_CF_IF_MISSING = True

# 可选：如果你想手动强制重训，改成 True
FORCE_RETRAIN_AR = False
FORCE_RETRAIN_CF = False

# Hybrid权重
AR_WEIGHT = 0.4
CF_WEIGHT = 0.6

# 可选：是否自动搜索更优权重
TUNE_HYBRID_WEIGHTS = True

# %%
# ====================== Load Data ======================
implicit_ratings = pd.read_csv("../data/processed/implicit_ratings.csv")
prior = pd.read_csv("../data/processed/prior_filtered.csv")
products = pd.read_csv("../data/raw/products.csv")

print(f"implicit_ratings: {len(implicit_ratings):,} rows")
print(f"prior: {len(prior):,} rows")
print(f"products: {len(products):,} rows")
print(f"users: {implicit_ratings['user_id'].nunique():,}, items: {implicit_ratings['product_id'].nunique():,}")
# Out:
# implicit_ratings: 12,083,736 rows
# prior: 30,718,986 rows
# products: 49,688 rows
# users: 162,381, items: 35,922

# %%
# ====================== Per-user Split (for offline evaluation) ======================

def per_user_split_df(df_in, test_ratio=0.2, seed=42):
    rng_local = np.random.RandomState(seed)
    tr_list, te_list = [], []
    for _, g in df_in.groupby("user_id"):
        n = len(g)
        k = max(1, int(np.floor(test_ratio * n)))
        idx = rng_local.choice(g.index, size=k, replace=False)
        te_list.append(g.loc[idx])
        tr_list.append(g.drop(idx))
    tr = pd.concat(tr_list).reset_index(drop=True)
    te = pd.concat(te_list).reset_index(drop=True)
    return tr, te

cnt = implicit_ratings.groupby("user_id").size()
eligible_users = cnt[cnt >= 5].index
cf_df = implicit_ratings[implicit_ratings["user_id"].isin(eligible_users)].copy()

train_ratings, test_ratings = per_user_split_df(cf_df, test_ratio=0.2, seed=42)

print("Train rows:", len(train_ratings), "Test rows:", len(test_ratings))
print("Train users:", train_ratings["user_id"].nunique(), "Test users:", test_ratings["user_id"].nunique())
print("User overlap:", test_ratings["user_id"].isin(train_ratings["user_id"]).mean())
print("Item overlap:", test_ratings["product_id"].isin(train_ratings["product_id"]).mean())
# Out:
# Train rows: 9727302 Test rows: 2351910
# Train users: 160932 Test users: 160932
# User overlap: 1.0
# Item overlap: 1.0

# %%
# ====================== Load/Train CF Model ======================
if CF_PATH.exists() and not FORCE_RETRAIN_CF:
    print(f"Loading CF model from {CF_PATH}")
    cf_model = CollaborativeFilteringModel.load(str(CF_PATH))
else:
    if not RETRAIN_CF_IF_MISSING and not FORCE_RETRAIN_CF:
        raise FileNotFoundError(f"CF checkpoint missing: {CF_PATH}")

    print("Training CF model from scratch...")
    cf_model = CollaborativeFilteringModel(
        method='als',
        n_factors=64,
        regularization=0.05,
        iterations=20,
        alpha=20.0,
        fallback_on_invalid=False,
    )
    cf_model.fit(train_ratings)
    cf_model.save(str(CF_PATH))
    print(f"Saved CF model -> {CF_PATH}")

# 即使是加载模型，也在当前test上做一次离线评估
metrics_cf = cf_model.evaluate(test_ratings)
print("CF core metrics:", {k: metrics_cf.get(k) for k in ["rmse","mae","correlation","coverage"]})
# Out:
# Loading CF model from ../models/cf_model_als.pkl
# INFO:src.models.collaborative_filtering:Model loaded from ../models/cf_model_als.pkl
# INFO:src.models.collaborative_filtering:Evaluating model...
# INFO:src.models.collaborative_filtering:Eval diagnostics: cold_start_user_rate=0.00%, cold_start_item_rate=0.00%, in_matrix_rate=100.00%
# INFO:src.models.collaborative_filtering:Eval diagnostics: dropped_empty_items=0
# INFO:src.models.collaborative_filtering:RMSE: 0.3026
# INFO:src.models.collaborative_filtering:MAE: 0.2161
# INFO:src.models.collaborative_filtering:Correlation: 0.3204
# INFO:src.models.collaborative_filtering:Spearman Correlation: 0.2144
# INFO:src.models.collaborative_filtering:Coverage (all test rows): 100.00%
# INFO:src.models.collaborative_filtering:Coverage (in-matrix rows only): 100.00%
# INFO:src.models.collaborative_filtering:Fallback rate (in-matrix): 0.00% | Non-finite drop rate (in-matrix): 0.00%
# INFO:src.models.collaborative_filtering:Predict status counts: {'ok': 2351910}
# CF core metrics: {'rmse': 0.3026467583740583, 'mae': 0.21605173041505613, 'correlation': 0.3203880912527413, 'coverage': 1.0}

# %%
# ====================== Load/Train AR Model ======================
if AR_PATH.exists() and not FORCE_RETRAIN_AR:
    print(f"Loading AR model from {AR_PATH}")
    ar_model = AssociationRuleModel.load(str(AR_PATH))
else:
    if not RETRAIN_AR_IF_MISSING and not FORCE_RETRAIN_AR:
        raise FileNotFoundError(f"AR checkpoint missing: {AR_PATH}")

    print("Training AR model from scratch...")
    ar_model = AssociationRuleModel(
        min_support=0.005,
        min_confidence=0.1,
        min_lift=2.0,
        max_len=2,
    )
    ar_model.fit(prior, top_k_products=1000)
    ar_model.save(str(AR_PATH))
    print(f"Saved AR model -> {AR_PATH}")

print(f"AR rules: {len(ar_model.rules):,}")
# Out:
# INFO:src.models.association_rules:Model loaded from ../models/association_rule_model.pkl
# Loading AR model from ../models/association_rule_model.pkl
# AR rules: 277

# %%
def _get_user_history(self, user_id: int, top_k: int = 30):
    """Get user's interacted products from CF training matrix (by row strength)."""
    if (
        getattr(self.cf_model, "user_encoder", None) is None
        or getattr(self.cf_model, "user_item_matrix", None) is None
        or getattr(self.cf_model, "product_decoder", None) is None
    ):
        return []

    user_keys = self.cf_model.user_encoder
    if len(user_keys) == 0:
        return []

    # best-effort cast to encoder key type
    try:
        key_type = type(next(iter(user_keys.keys())))
        user_key = key_type(user_id)
    except Exception:
        user_key = user_id

    if user_key not in user_keys:
        return []

    user_idx = int(user_keys[user_key])
    row = self.cf_model.user_item_matrix.tocsr()[user_idx]

    if row.nnz == 0:
        return []

    # Sort by interaction strength descending
    order = np.argsort(row.data)[::-1]
    item_indices = row.indices[order]
    if top_k is not None and top_k > 0:
        item_indices = item_indices[:top_k]

    history = []
    for col_idx in item_indices:
        pid = self.cf_model.product_decoder.get(int(col_idx))
        if pid is not None:
            history.append(pid)

    return history

# %%
def recommend_for_user(
    self,
    user_id: int,
    top_n: int = 10,
    exclude_purchased: bool = True,) :
    """
    Hybrid user recommendations:
    - CF personalized candidates
    - AR candidates expanded from user's historical products
    - Weighted fusion of normalized scores
    """
    # 1) CF candidates
    cf_recs = self.cf_model.get_recommendations(
        user_id,
        top_n=top_n * 5,
        exclude_purchased=exclude_purchased,
    )
    cf_norm = self._normalize_scores(cf_recs)

    # 2) AR candidates from user history
    user_history = self._get_user_history(user_id, top_k=30)
    ar_agg = {}  # pid -> best lift

    for seed_pid in user_history:
        ar_recs = self.ar_model.get_recommendations(int(seed_pid), top_n=top_n * 3, only_pairs=True)
        for rec_pid, lift in ar_recs:
            if rec_pid == seed_pid:
                continue
            score = float(lift)
            if (rec_pid not in ar_agg) or (score > ar_agg[rec_pid]):
                ar_agg[rec_pid] = score

    ar_norm = self._normalize_scores(list(ar_agg.items()))

    # 3) Merge candidate pool
    candidate_ids = set(cf_norm.keys()) | set(ar_norm.keys())
    if exclude_purchased:
        purchased = set(user_history)
        candidate_ids = {pid for pid in candidate_ids if pid not in purchased}

    if not candidate_ids:
        logger.warning(f"No hybrid recommendations for user {user_id}")
        return []

    # 4) Weighted fusion
    hybrid_scores = []
    for pid in candidate_ids:
        ar_s = ar_norm.get(pid, 0.0)
        cf_s = cf_norm.get(pid, 0.0)
        score = self.ar_weight * ar_s + self.cf_weight * cf_s

        if ar_s > 0 and cf_s > 0:
            source = "HYBRID"
        elif cf_s > 0:
            source = "CF"
        else:
            source = "AR"

        hybrid_scores.append((pid, float(score), source))

    hybrid_scores.sort(key=lambda x: x[1], reverse=True)
    return hybrid_scores[:top_n]

# %%
# ====================== Build Hybrid ======================
hybrid = HybridRecommender(
    ar_model=ar_model,
    cf_model=cf_model,
    ar_weight=AR_WEIGHT,
    cf_weight=CF_WEIGHT,
)

# 建一个 product_id -> product_name 的字典，打印更快
product_name_map = products.set_index("product_id")["product_name"].to_dict()

def name_of(pid):
    try:
        return product_name_map.get(int(pid), f"Product {pid}")
    except Exception:
        return f"Product {pid}"

def display_recs_with_names(recs, title, top_n=5):
    print(title)
    if not recs:
        print("  (no recommendations)")
        return
    for i, (pid, score, source) in enumerate(recs[:top_n], 1):
        print(f"  {i}. {name_of(pid)} | id={pid} | score={score:.4f} | source={source}")

sample_user = np.random.choice(train_ratings["user_id"].unique())
recs_user = hybrid.recommend_for_user(sample_user, top_n=10)
print("sample user:", sample_user)
display_recs_with_names(recs_user, "top-5 user recs（For you）:", top_n=5)

sample_basket = train_ratings[train_ratings["user_id"] == sample_user]["product_id"].head(3).tolist()
print("sample basket product_ids(购物车页 “Frequently bought together):", sample_basket)
recs_basket = hybrid.recommend_for_basket(sample_basket, user_id=sample_user, top_n=10)
display_recs_with_names(recs_basket, "top-5 basket recs:", top_n=5)
# Out:
# sample user: 170183
# top-5 user recs（For you）:
#   1. Organic Cucumber | id=30391 | score=0.7330 | source=HYBRID
#   2. Organic Baby Spinach | id=21903 | score=0.6554 | source=HYBRID
#   3. Organic Italian Parsley Bunch | id=34126 | score=0.6456 | source=HYBRID
#   4. Organic Yellow Onion | id=22935 | score=0.6172 | source=HYBRID
#   5. Half & Half | id=27086 | score=0.5896 | source=CF
# sample basket product_ids(购物车页 “Frequently bought together): [1463, 1658, 1947]
# top-5 basket recs:
#   1. Organic Baby Spinach | id=21903 | score=0.6000 | source=CF
#   2. Half & Half | id=27086 | score=0.5840 | source=CF
#   3. Organic Cucumber | id=30391 | score=0.3183 | source=CF
#   4. Organic Reduced Fat 2% Milk | id=5785 | score=0.2331 | source=CF
#   5. Spring Water | id=19660 | score=0.2202 | source=CF

# %%
# ====================== Evaluate Hybrid (user-side Hit@K) ======================

def evaluate_user_hitk(model_hybrid, test_df, k=10, max_users=5000, seed=42):
    rng_local = np.random.RandomState(seed)
    user_to_items = test_df.groupby("user_id")["product_id"].apply(set)
    users = np.array(list(user_to_items.index))
    if len(users) > max_users:
        users = rng_local.choice(users, size=max_users, replace=False)

    hits = 0
    precisions = []
    recalls = []

    for u in users:
        gt = user_to_items[u]
        recs = model_hybrid.recommend_for_user(u, top_n=k, exclude_purchased=True)
        rec_items = [pid for pid, _, _ in recs]

        if not rec_items:
            precisions.append(0.0)
            recalls.append(0.0)
            continue

        inter = len(set(rec_items) & gt)
        if inter > 0:
            hits += 1
        precisions.append(inter / k)
        recalls.append(inter / max(1, len(gt)))

    n = len(users)
    return {
        "users_evaluated": int(n),
        "hit_rate@k": hits / n if n else 0.0,
        "precision@k": float(np.mean(precisions)) if precisions else 0.0,
        "recall@k": float(np.mean(recalls)) if recalls else 0.0,
    }

hybrid_user_eval = evaluate_user_hitk(hybrid, test_ratings, k=10, max_users=5000, seed=42)
print("Hybrid user eval:", hybrid_user_eval)
# Out:
# Hybrid user eval: {'users_evaluated': 5000, 'hit_rate@k': 0.443, 'precision@k': 0.07374, 'recall@k': 0.05914282647650266}

# %%
# ====================== Optional: Tune Hybrid Weights ======================
if TUNE_HYBRID_WEIGHTS:
    weight_grid = [
        (0.2, 0.8),
        (0.3, 0.7),
        (0.4, 0.6),
        (0.5, 0.5),
        (0.6, 0.4),
    ]

    tune_rows = []
    for ar_w, cf_w in weight_grid:
        h = HybridRecommender(
            ar_model=ar_model,
            cf_model=cf_model,
            ar_weight=ar_w,
            cf_weight=cf_w,
        )
        m = evaluate_user_hitk(h, test_ratings, k=10, max_users=3000, seed=42)
        tune_rows.append({
            "ar_weight": ar_w,
            "cf_weight": cf_w,
            **m,
        })

    tune_df = pd.DataFrame(tune_rows).sort_values("hit_rate@k", ascending=False).reset_index(drop=True)
    print(tune_df)

    best = tune_df.iloc[0]
    print("Best hybrid weights:", {"ar_weight": best["ar_weight"], "cf_weight": best["cf_weight"]})
    """
    hybrid = HybridRecommender(
        ar_model=ar_model,
        cf_model=cf_model,
        ar_weight=float(best["ar_weight"]),
        cf_weight=float(best["cf_weight"]),
    )
    """
    hybrid = HybridRecommender(
    ar_model=ar_model,
    cf_model=cf_model,
    ar_weight=AR_WEIGHT,
    cf_weight=CF_WEIGHT,
    enable_fallback=True,                 
    cf_user_candidate_multiplier=20,
    ar_user_seed_multiplier=5,
    ar_basket_candidate_multiplier=4,
    cf_basket_candidate_multiplier=2,
    ar_basket_require_full_match=False,
    ar_basket_min_overlap=1,
    ar_basket_overlap_weighted=True,
)
# Out:
#    ar_weight  cf_weight  users_evaluated  hit_rate@k  precision@k  recall@k
# 0        0.6        0.4             3000    0.435000     0.071833  0.059336
# 1        0.3        0.7             3000    0.432667     0.072333  0.059372
# 2        0.4        0.6             3000    0.432333     0.071733  0.058577
# 3        0.5        0.5             3000    0.432000     0.071433  0.058364
# 4        0.2        0.8             3000    0.430000     0.071933  0.059372
# Best hybrid weights: {'ar_weight': np.float64(0.6), 'cf_weight': np.float64(0.4)}

# %%
cold_user = int(train_ratings["user_id"].max()) + 10_000_000
cold_recs = hybrid.recommend_for_user(cold_user, top_n=10, exclude_purchased=True)
print(cold_recs[:5])   # 这里 source 应该能看到 FALLBACK_POPULAR
# Out:
# WARNING:src.models.collaborative_filtering:User 10206209 not in training data
# INFO:src.models.hybrid_recommender:User 10206209 fallback recommendations returned: 10
# [(np.int64(24852), 1.0, 'FALLBACK_POPULAR'), (np.int64(13176), 0.7229090653523066, 'FALLBACK_POPULAR'), (np.int64(21137), 0.47466658454831134, 'FALLBACK_POPULAR'), (np.int64(21903), 0.42770689916620364, 'FALLBACK_POPULAR'), (np.int64(47209), 0.258715910259973, 'FALLBACK_POPULAR')]

# %%
# ====================== Save Hybrid-Context Checkpoints (optional names) ======================
# 这里只是另存一份，避免覆盖你主流程checkpoint
CF_HYBRID_PATH = MODELS_DIR / "cf_model_hybrid_als.pkl"
AR_HYBRID_PATH = MODELS_DIR / "association_rule_model_hybrid.pkl"

cf_model.save(str(CF_HYBRID_PATH))
ar_model.save(str(AR_HYBRID_PATH))

print("Saved:")
print(CF_HYBRID_PATH)
print(AR_HYBRID_PATH)
# Out:
# INFO:src.models.collaborative_filtering:Model saved to ../models/cf_model_hybrid_als.pkl
# INFO:src.models.association_rules:Model saved to ../models/association_rule_model_hybrid.pkl
# Saved:
# ../models/cf_model_hybrid_als.pkl
# ../models/association_rule_model_hybrid.pkl

# %%
# ====================== Evaluate Hybrid at Multiple K ======================
def evaluate_user_hitk(model_hybrid, test_df, k=10, max_users=5000, seed=42):
    rng_local = np.random.RandomState(seed)
    user_to_items = test_df.groupby("user_id")["product_id"].apply(set)
    users = np.array(list(user_to_items.index))
    if len(users) > max_users:
        users = rng_local.choice(users, size=max_users, replace=False)

    hits = 0
    precisions = []
    recalls = []

    for u in users:
        gt = user_to_items[u]
        recs = model_hybrid.recommend_for_user(u, top_n=k, exclude_purchased=True)
        rec_items = [pid for pid, _, _ in recs]

        if not rec_items:
            precisions.append(0.0)
            recalls.append(0.0)
            continue

        inter = len(set(rec_items) & gt)
        if inter > 0:
            hits += 1
        precisions.append(inter / k)
        recalls.append(inter / max(1, len(gt)))

    n = len(users)
    return {
        "users_evaluated": int(n),
        "hit_rate": hits / n if n else 0.0,
        "precision": float(np.mean(precisions)) if precisions else 0.0,
        "recall": float(np.mean(recalls)) if recalls else 0.0,
    }

K_LIST = [5, 10, 20]
rows = []

for k in K_LIST:
    m = evaluate_user_hitk(hybrid, test_ratings, k=k, max_users=5000, seed=42)
    rows.append({
        "k": k,
        "users_evaluated": int(m["users_evaluated"]),
        "hit_rate": float(m["hit_rate"]),
        "precision": float(m["precision"]),
        "recall": float(m["recall"]),
    })

eval_k_df = pd.DataFrame(rows).sort_values("k").reset_index(drop=True)

# optional: nicer display
eval_k_df["hit_rate"] = eval_k_df["hit_rate"].map(lambda x: f"{x:.4f}")
eval_k_df["precision"] = eval_k_df["precision"].map(lambda x: f"{x:.4f}")
eval_k_df["recall"] = eval_k_df["recall"].map(lambda x: f"{x:.4f}")

eval_k_df
# Out:
#     k  users_evaluated hit_rate precision  recall
# 0   5             5000   0.3276    0.0902  0.0371
# 1  10             5000   0.4430    0.0737  0.0591
# 2  20             5000   0.5522    0.0582  0.0907

# %%
# ====================== MIXED WARM/COLD EVALUATION (INDUSTRY-STYLE TOLERANCE) ======================

def _prh_at_k(rec_items, gt_items, k):
    rec_set = set(rec_items[:k])
    gt_set = set(gt_items)
    inter = len(rec_set & gt_set)
    hit = 1.0 if inter > 0 else 0.0
    precision = inter / max(1, k)
    recall = inter / max(1, len(gt_set))
    return hit, precision, recall

def evaluate_mixed_cold_start(
    model_hybrid,
    test_df,
    cold_user_ratio=0.10,
    k=10,
    basket_seed_k=3,
    max_users=3000,
    seed=42,
):
    rng = np.random.RandomState(seed)
    user_to_items = test_df.groupby("user_id")["product_id"].apply(list)
    users = np.array(list(user_to_items.index))
    if len(users) > max_users:
        users = rng.choice(users, size=max_users, replace=False)

    n_users = len(users)
    n_cold = int(round(n_users * cold_user_ratio))
    cold_users = set(rng.choice(users, size=n_cold, replace=False)) if n_cold > 0 else set()

    user_hits, user_precs, user_recalls = [], [], []
    basket_hits, basket_precs, basket_recalls = [], [], []
    serve_hits, serve_precs, serve_recalls = [], [], []

    for idx, u in enumerate(users):
        items = list(dict.fromkeys(user_to_items[u]))  # dedup keep order
        if len(items) == 0:
            continue

        seed_items = items[:min(basket_seed_k, len(items))]
        gt_items = items[min(basket_seed_k, len(items)):]
        if len(gt_items) == 0:
            gt_items = items

        is_cold = u in cold_users
        if is_cold:
            cold_uid = int(u) + 10_000_000 + idx
            user_recs = model_hybrid.recommend_for_user(cold_uid, top_n=k, exclude_purchased=True)
            basket_recs = model_hybrid.recommend_for_basket(seed_items, user_id=None, top_n=k)
        else:
            user_recs = model_hybrid.recommend_for_user(int(u), top_n=k, exclude_purchased=True)
            basket_recs = model_hybrid.recommend_for_basket(seed_items, user_id=int(u), top_n=k)

        user_items = [pid for pid, _, _ in user_recs]
        basket_items = [pid for pid, _, _ in basket_recs]
        served_items = user_items if len(user_items) > 0 else basket_items

        h, p, r = _prh_at_k(user_items, gt_items, k)
        user_hits.append(h); user_precs.append(p); user_recalls.append(r)

        h, p, r = _prh_at_k(basket_items, gt_items, k)
        basket_hits.append(h); basket_precs.append(p); basket_recalls.append(r)

        h, p, r = _prh_at_k(served_items, gt_items, k)
        serve_hits.append(h); serve_precs.append(p); serve_recalls.append(r)

    def _mean(x):
        return float(np.mean(x)) if len(x) > 0 else 0.0

    return {
        "users_evaluated": int(len(user_hits)),
        "cold_user_ratio": float(cold_user_ratio),
        "user_hit_rate@k": _mean(user_hits),
        "user_precision@k": _mean(user_precs),
        "user_recall@k": _mean(user_recalls),
        "basket_hit_rate@k": _mean(basket_hits),
        "basket_precision@k": _mean(basket_precs),
        "basket_recall@k": _mean(basket_recalls),
        "served_hit_rate@k": _mean(serve_hits),
        "served_precision@k": _mean(serve_precs),
        "served_recall@k": _mean(serve_recalls),
    }

ratios = [0.10, 0.15, 0.20]
rows = []
for r in ratios:
    m = evaluate_mixed_cold_start(
        hybrid,
        test_ratings,
        cold_user_ratio=r,
        k=10,
        basket_seed_k=3,
        max_users=3000,
        seed=42,
    )
    rows.append(m)

mixed_cs_df = pd.DataFrame(rows)
print(mixed_cs_df[[
    "cold_user_ratio", "users_evaluated",
    "user_hit_rate@k", "basket_hit_rate@k", "served_hit_rate@k",
    "user_precision@k", "basket_precision@k", "served_precision@k",
    "user_recall@k", "basket_recall@k", "served_recall@k",
]])
# Out:
# WARNING:src.models.collaborative_filtering:User 10183713 not in training data
# INFO:src.models.hybrid_recommender:User 10183713 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10106533 not in training data
# INFO:src.models.hybrid_recommender:User 10106533 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10140038 not in training data
# INFO:src.models.hybrid_recommender:User 10140038 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10140833 not in training data
# INFO:src.models.hybrid_recommender:User 10140833 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10105742 not in training data
# INFO:src.models.hybrid_recommender:User 10105742 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10146672 not in training data
# INFO:src.models.hybrid_recommender:User 10146672 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10196451 not in training data
# INFO:src.models.hybrid_recommender:User 10196451 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10202455 not in training data
# INFO:src.models.hybrid_recommender:User 10202455 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10007175 not in training data
# INFO:src.models.hybrid_recommender:User 10007175 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10197184 not in training data
# INFO:src.models.hybrid_recommender:User 10197184 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10191665 not in training data
# INFO:src.models.hybrid_recommender:User 10191665 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10144837 not in training data
# INFO:src.models.hybrid_recommender:User 10144837 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10053468 not in training data
# INFO:src.models.hybrid_recommender:User 10053468 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10140463 not in training data
# INFO:src.models.hybrid_recommender:User 10140463 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10037382 not in training data
# INFO:src.models.hybrid_recommender:User 10037382 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10070181 not in training data
# INFO:src.models.hybrid_recommender:User 10070181 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10080647 not in training data
# INFO:src.models.hybrid_recommender:User 10080647 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10135545 not in training data
# INFO:src.models.hybrid_recommender:User 10135545 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10205136 not in training data
# INFO:src.models.hybrid_recommender:User 10205136 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10030640 not in training data
# INFO:src.models.hybrid_recommender:User 10030640 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10181286 not in training data
# INFO:src.models.hybrid_recommender:User 10181286 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10079421 not in training data
# INFO:src.models.hybrid_recommender:User 10079421 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10101595 not in training data
# INFO:src.models.hybrid_recommender:User 10101595 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10021043 not in training data
# INFO:src.models.hybrid_recommender:User 10021043 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10101280 not in training data
# INFO:src.models.hybrid_recommender:User 10101280 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10206015 not in training data
# INFO:src.models.hybrid_recommender:User 10206015 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10177201 not in training data
# INFO:src.models.hybrid_recommender:User 10177201 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10011701 not in training data
# INFO:src.models.hybrid_recommender:User 10011701 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10076721 not in training data
# INFO:src.models.hybrid_recommender:User 10076721 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10192017 not in training data
# INFO:src.models.hybrid_recommender:User 10192017 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10035866 not in training data
# INFO:src.models.hybrid_recommender:User 10035866 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10154299 not in training data
# INFO:src.models.hybrid_recommender:User 10154299 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10047966 not in training data
# INFO:src.models.hybrid_recommender:User 10047966 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10181800 not in training data
# INFO:src.models.hybrid_recommender:User 10181800 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10079352 not in training data
# INFO:src.models.hybrid_recommender:User 10079352 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10163874 not in training data
# INFO:src.models.hybrid_recommender:User 10163874 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10170531 not in training data
# INFO:src.models.hybrid_recommender:User 10170531 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10194513 not in training data
# INFO:src.models.hybrid_recommender:User 10194513 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10076015 not in training data
# INFO:src.models.hybrid_recommender:User 10076015 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10034201 not in training data
# INFO:src.models.hybrid_recommender:User 10034201 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10184800 not in training data
# INFO:src.models.hybrid_recommender:User 10184800 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10043640 not in training data
# INFO:src.models.hybrid_recommender:User 10043640 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10092999 not in training data
# INFO:src.models.hybrid_recommender:User 10092999 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10034001 not in training data
# INFO:src.models.hybrid_recommender:User 10034001 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10034661 not in training data
# INFO:src.models.hybrid_recommender:User 10034661 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10155439 not in training data
# INFO:src.models.hybrid_recommender:User 10155439 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10008464 not in training data
# INFO:src.models.hybrid_recommender:User 10008464 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10068007 not in training data
# INFO:src.models.hybrid_recommender:User 10068007 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10182927 not in training data
# INFO:src.models.hybrid_recommender:User 10182927 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10130398 not in training data
# INFO:src.models.hybrid_recommender:User 10130398 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10122775 not in training data
# INFO:src.models.hybrid_recommender:User 10122775 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10037994 not in training data
# INFO:src.models.hybrid_recommender:User 10037994 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10118231 not in training data
# INFO:src.models.hybrid_recommender:User 10118231 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10047867 not in training data
# INFO:src.models.hybrid_recommender:User 10047867 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10092465 not in training data
# INFO:src.models.hybrid_recommender:User 10092465 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10136350 not in training data
# INFO:src.models.hybrid_recommender:User 10136350 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10131344 not in training data
# INFO:src.models.hybrid_recommender:User 10131344 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10203261 not in training data
# INFO:src.models.hybrid_recommender:User 10203261 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10025154 not in training data
# INFO:src.models.hybrid_recommender:User 10025154 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10014303 not in training data
# INFO:src.models.hybrid_recommender:User 10014303 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10174643 not in training data
# INFO:src.models.hybrid_recommender:User 10174643 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10041832 not in training data
# INFO:src.models.hybrid_recommender:User 10041832 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10041688 not in training data
# INFO:src.models.hybrid_recommender:User 10041688 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10163107 not in training data
# INFO:src.models.hybrid_recommender:User 10163107 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10179328 not in training data
# INFO:src.models.hybrid_recommender:User 10179328 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10007580 not in training data
# INFO:src.models.hybrid_recommender:User 10007580 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10049148 not in training data
# INFO:src.models.hybrid_recommender:User 10049148 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10055902 not in training data
# INFO:src.models.hybrid_recommender:User 10055902 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10130075 not in training data
# INFO:src.models.hybrid_recommender:User 10130075 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10140732 not in training data
# INFO:src.models.hybrid_recommender:User 10140732 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10105731 not in training data
# INFO:src.models.hybrid_recommender:User 10105731 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10110066 not in training data
# INFO:src.models.hybrid_recommender:User 10110066 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10190701 not in training data
# INFO:src.models.hybrid_recommender:User 10190701 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10168960 not in training data
# INFO:src.models.hybrid_recommender:User 10168960 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10108094 not in training data
# INFO:src.models.hybrid_recommender:User 10108094 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10088990 not in training data
# INFO:src.models.hybrid_recommender:User 10088990 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10132624 not in training data
# INFO:src.models.hybrid_recommender:User 10132624 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10162555 not in training data
# INFO:src.models.hybrid_recommender:User 10162555 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10029820 not in training data
# INFO:src.models.hybrid_recommender:User 10029820 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10095238 not in training data
# INFO:src.models.hybrid_recommender:User 10095238 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10040417 not in training data
# INFO:src.models.hybrid_recommender:User 10040417 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10093732 not in training data
# INFO:src.models.hybrid_recommender:User 10093732 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10091956 not in training data
# INFO:src.models.hybrid_recommender:User 10091956 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10186723 not in training data
# INFO:src.models.hybrid_recommender:User 10186723 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10077117 not in training data
# INFO:src.models.hybrid_recommender:User 10077117 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10031171 not in training data
# INFO:src.models.hybrid_recommender:User 10031171 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10161066 not in training data
# INFO:src.models.hybrid_recommender:User 10161066 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10158598 not in training data
# INFO:src.models.hybrid_recommender:User 10158598 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10134801 not in training data
# INFO:src.models.hybrid_recommender:User 10134801 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10144941 not in training data
# INFO:src.models.hybrid_recommender:User 10144941 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10072009 not in training data
# INFO:src.models.hybrid_recommender:User 10072009 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10091604 not in training data
# INFO:src.models.hybrid_recommender:User 10091604 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10206965 not in training data
# INFO:src.models.hybrid_recommender:User 10206965 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10026333 not in training data
# INFO:src.models.hybrid_recommender:User 10026333 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10063009 not in training data
# INFO:src.models.hybrid_recommender:User 10063009 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10135328 not in training data
# INFO:src.models.hybrid_recommender:User 10135328 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10091343 not in training data
# INFO:src.models.hybrid_recommender:User 10091343 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10073897 not in training data
# INFO:src.models.hybrid_recommender:User 10073897 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10123360 not in training data
# INFO:src.models.hybrid_recommender:User 10123360 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10109376 not in training data
# INFO:src.models.hybrid_recommender:User 10109376 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10187447 not in training data
# INFO:src.models.hybrid_recommender:User 10187447 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10194475 not in training data
# INFO:src.models.hybrid_recommender:User 10194475 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10142182 not in training data
# INFO:src.models.hybrid_recommender:User 10142182 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10125179 not in training data
# INFO:src.models.hybrid_recommender:User 10125179 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10069144 not in training data
# INFO:src.models.hybrid_recommender:User 10069144 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10021592 not in training data
# INFO:src.models.hybrid_recommender:User 10021592 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10169506 not in training data
# INFO:src.models.hybrid_recommender:User 10169506 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10088806 not in training data
# INFO:src.models.hybrid_recommender:User 10088806 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10093612 not in training data
# INFO:src.models.hybrid_recommender:User 10093612 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10107107 not in training data
# INFO:src.models.hybrid_recommender:User 10107107 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10201226 not in training data
# INFO:src.models.hybrid_recommender:User 10201226 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10191825 not in training data
# INFO:src.models.hybrid_recommender:User 10191825 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10181130 not in training data
# INFO:src.models.hybrid_recommender:User 10181130 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10091152 not in training data
# INFO:src.models.hybrid_recommender:User 10091152 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10150316 not in training data
# INFO:src.models.hybrid_recommender:User 10150316 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10034715 not in training data
# INFO:src.models.hybrid_recommender:User 10034715 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10084485 not in training data
# INFO:src.models.hybrid_recommender:User 10084485 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10090620 not in training data
# INFO:src.models.hybrid_recommender:User 10090620 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10119218 not in training data
# INFO:src.models.hybrid_recommender:User 10119218 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10198117 not in training data
# INFO:src.models.hybrid_recommender:User 10198117 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10103339 not in training data
# INFO:src.models.hybrid_recommender:User 10103339 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10179688 not in training data
# INFO:src.models.hybrid_recommender:User 10179688 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10175826 not in training data
# INFO:src.models.hybrid_recommender:User 10175826 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10103897 not in training data
# INFO:src.models.hybrid_recommender:User 10103897 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10132620 not in training data
# INFO:src.models.hybrid_recommender:User 10132620 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10081151 not in training data
# INFO:src.models.hybrid_recommender:User 10081151 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10153225 not in training data
# INFO:src.models.hybrid_recommender:User 10153225 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10039606 not in training data
# INFO:src.models.hybrid_recommender:User 10039606 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10113657 not in training data
# INFO:src.models.hybrid_recommender:User 10113657 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10108020 not in training data
# INFO:src.models.hybrid_recommender:User 10108020 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10071209 not in training data
# INFO:src.models.hybrid_recommender:User 10071209 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10163363 not in training data
# INFO:src.models.hybrid_recommender:User 10163363 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10118330 not in training data
# INFO:src.models.hybrid_recommender:User 10118330 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10108888 not in training data
# INFO:src.models.hybrid_recommender:User 10108888 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10182560 not in training data
# INFO:src.models.hybrid_recommender:User 10182560 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10146159 not in training data
# INFO:src.models.hybrid_recommender:User 10146159 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10171164 not in training data
# INFO:src.models.hybrid_recommender:User 10171164 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10136795 not in training data
# INFO:src.models.hybrid_recommender:User 10136795 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10131145 not in training data
# INFO:src.models.hybrid_recommender:User 10131145 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10166015 not in training data
# INFO:src.models.hybrid_recommender:User 10166015 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10132106 not in training data
# INFO:src.models.hybrid_recommender:User 10132106 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10088605 not in training data
# INFO:src.models.hybrid_recommender:User 10088605 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10149697 not in training data
# INFO:src.models.hybrid_recommender:User 10149697 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10114964 not in training data
# INFO:src.models.hybrid_recommender:User 10114964 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10003687 not in training data
# INFO:src.models.hybrid_recommender:User 10003687 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10124236 not in training data
# INFO:src.models.hybrid_recommender:User 10124236 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10112685 not in training data
# INFO:src.models.hybrid_recommender:User 10112685 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10098651 not in training data
# INFO:src.models.hybrid_recommender:User 10098651 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10162962 not in training data
# INFO:src.models.hybrid_recommender:User 10162962 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10066830 not in training data
# INFO:src.models.hybrid_recommender:User 10066830 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10025777 not in training data
# INFO:src.models.hybrid_recommender:User 10025777 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10194822 not in training data
# INFO:src.models.hybrid_recommender:User 10194822 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10031511 not in training data
# INFO:src.models.hybrid_recommender:User 10031511 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10029257 not in training data
# INFO:src.models.hybrid_recommender:User 10029257 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10159728 not in training data
# INFO:src.models.hybrid_recommender:User 10159728 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10079018 not in training data
# INFO:src.models.hybrid_recommender:User 10079018 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10121665 not in training data
# INFO:src.models.hybrid_recommender:User 10121665 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10093802 not in training data
# INFO:src.models.hybrid_recommender:User 10093802 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10094511 not in training data
# INFO:src.models.hybrid_recommender:User 10094511 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10133332 not in training data
# INFO:src.models.hybrid_recommender:User 10133332 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10043408 not in training data
# INFO:src.models.hybrid_recommender:User 10043408 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10012299 not in training data
# INFO:src.models.hybrid_recommender:User 10012299 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10042006 not in training data
# INFO:src.models.hybrid_recommender:User 10042006 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10188221 not in training data
# INFO:src.models.hybrid_recommender:User 10188221 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10037850 not in training data
# INFO:src.models.hybrid_recommender:User 10037850 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10194697 not in training data
# INFO:src.models.hybrid_recommender:User 10194697 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10111603 not in training data
# INFO:src.models.hybrid_recommender:User 10111603 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10022898 not in training data
# INFO:src.models.hybrid_recommender:User 10022898 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10032221 not in training data
# INFO:src.models.hybrid_recommender:User 10032221 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10163794 not in training data
# INFO:src.models.hybrid_recommender:User 10163794 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10079334 not in training data
# INFO:src.models.hybrid_recommender:User 10079334 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10204860 not in training data
# INFO:src.models.hybrid_recommender:User 10204860 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10051625 not in training data
# INFO:src.models.hybrid_recommender:User 10051625 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10021480 not in training data
# INFO:src.models.hybrid_recommender:User 10021480 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10071950 not in training data
# INFO:src.models.hybrid_recommender:User 10071950 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10050675 not in training data
# INFO:src.models.hybrid_recommender:User 10050675 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10087710 not in training data
# INFO:src.models.hybrid_recommender:User 10087710 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10173229 not in training data
# INFO:src.models.hybrid_recommender:User 10173229 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10005474 not in training data
# INFO:src.models.hybrid_recommender:User 10005474 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10107668 not in training data
# INFO:src.models.hybrid_recommender:User 10107668 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10186562 not in training data
# INFO:src.models.hybrid_recommender:User 10186562 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10030456 not in training data
# INFO:src.models.hybrid_recommender:User 10030456 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10123737 not in training data
# INFO:src.models.hybrid_recommender:User 10123737 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10170517 not in training data
# INFO:src.models.hybrid_recommender:User 10170517 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10170931 not in training data
# INFO:src.models.hybrid_recommender:User 10170931 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10173190 not in training data
# INFO:src.models.hybrid_recommender:User 10173190 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10174177 not in training data
# INFO:src.models.hybrid_recommender:User 10174177 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10094769 not in training data
# INFO:src.models.hybrid_recommender:User 10094769 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10069072 not in training data
# INFO:src.models.hybrid_recommender:User 10069072 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10017392 not in training data
# INFO:src.models.hybrid_recommender:User 10017392 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10180308 not in training data
# INFO:src.models.hybrid_recommender:User 10180308 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10148223 not in training data
# INFO:src.models.hybrid_recommender:User 10148223 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10200625 not in training data
# INFO:src.models.hybrid_recommender:User 10200625 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10192355 not in training data
# INFO:src.models.hybrid_recommender:User 10192355 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10047107 not in training data
# INFO:src.models.hybrid_recommender:User 10047107 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10178525 not in training data
# INFO:src.models.hybrid_recommender:User 10178525 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10073079 not in training data
# INFO:src.models.hybrid_recommender:User 10073079 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10186026 not in training data
# INFO:src.models.hybrid_recommender:User 10186026 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10123021 not in training data
# INFO:src.models.hybrid_recommender:User 10123021 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10177440 not in training data
# INFO:src.models.hybrid_recommender:User 10177440 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10088890 not in training data
# INFO:src.models.hybrid_recommender:User 10088890 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10080745 not in training data
# INFO:src.models.hybrid_recommender:User 10080745 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10154557 not in training data
# INFO:src.models.hybrid_recommender:User 10154557 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10087587 not in training data
# INFO:src.models.hybrid_recommender:User 10087587 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10180248 not in training data
# INFO:src.models.hybrid_recommender:User 10180248 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10149561 not in training data
# INFO:src.models.hybrid_recommender:User 10149561 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10154782 not in training data
# INFO:src.models.hybrid_recommender:User 10154782 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10007130 not in training data
# INFO:src.models.hybrid_recommender:User 10007130 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10008987 not in training data
# INFO:src.models.hybrid_recommender:User 10008987 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10160335 not in training data
# INFO:src.models.hybrid_recommender:User 10160335 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10073600 not in training data
# INFO:src.models.hybrid_recommender:User 10073600 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10174234 not in training data
# INFO:src.models.hybrid_recommender:User 10174234 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10100262 not in training data
# INFO:src.models.hybrid_recommender:User 10100262 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10184989 not in training data
# INFO:src.models.hybrid_recommender:User 10184989 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10080278 not in training data
# INFO:src.models.hybrid_recommender:User 10080278 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10178457 not in training data
# INFO:src.models.hybrid_recommender:User 10178457 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10003275 not in training data
# INFO:src.models.hybrid_recommender:User 10003275 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10205415 not in training data
# INFO:src.models.hybrid_recommender:User 10205415 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10044299 not in training data
# INFO:src.models.hybrid_recommender:User 10044299 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10016601 not in training data
# INFO:src.models.hybrid_recommender:User 10016601 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10095596 not in training data
# INFO:src.models.hybrid_recommender:User 10095596 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10026114 not in training data
# INFO:src.models.hybrid_recommender:User 10026114 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10154227 not in training data
# INFO:src.models.hybrid_recommender:User 10154227 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10154260 not in training data
# INFO:src.models.hybrid_recommender:User 10154260 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10083339 not in training data
# INFO:src.models.hybrid_recommender:User 10083339 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10042648 not in training data
# INFO:src.models.hybrid_recommender:User 10042648 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10147424 not in training data
# INFO:src.models.hybrid_recommender:User 10147424 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10158105 not in training data
# INFO:src.models.hybrid_recommender:User 10158105 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10120035 not in training data
# INFO:src.models.hybrid_recommender:User 10120035 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10163890 not in training data
# INFO:src.models.hybrid_recommender:User 10163890 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10008844 not in training data
# INFO:src.models.hybrid_recommender:User 10008844 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10019974 not in training data
# INFO:src.models.hybrid_recommender:User 10019974 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10117655 not in training data
# INFO:src.models.hybrid_recommender:User 10117655 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10106585 not in training data
# INFO:src.models.hybrid_recommender:User 10106585 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10162213 not in training data
# INFO:src.models.hybrid_recommender:User 10162213 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10131366 not in training data
# INFO:src.models.hybrid_recommender:User 10131366 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10174058 not in training data
# INFO:src.models.hybrid_recommender:User 10174058 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10161488 not in training data
# INFO:src.models.hybrid_recommender:User 10161488 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10016576 not in training data
# INFO:src.models.hybrid_recommender:User 10016576 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10184199 not in training data
# INFO:src.models.hybrid_recommender:User 10184199 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10119545 not in training data
# INFO:src.models.hybrid_recommender:User 10119545 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10060218 not in training data
# INFO:src.models.hybrid_recommender:User 10060218 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10119632 not in training data
# INFO:src.models.hybrid_recommender:User 10119632 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10093070 not in training data
# INFO:src.models.hybrid_recommender:User 10093070 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10070934 not in training data
# INFO:src.models.hybrid_recommender:User 10070934 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10149889 not in training data
# INFO:src.models.hybrid_recommender:User 10149889 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10204614 not in training data
# INFO:src.models.hybrid_recommender:User 10204614 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10006824 not in training data
# INFO:src.models.hybrid_recommender:User 10006824 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10111085 not in training data
# INFO:src.models.hybrid_recommender:User 10111085 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10083807 not in training data
# INFO:src.models.hybrid_recommender:User 10083807 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10035375 not in training data
# INFO:src.models.hybrid_recommender:User 10035375 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10178429 not in training data
# INFO:src.models.hybrid_recommender:User 10178429 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10056195 not in training data
# INFO:src.models.hybrid_recommender:User 10056195 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10043993 not in training data
# INFO:src.models.hybrid_recommender:User 10043993 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10112992 not in training data
# INFO:src.models.hybrid_recommender:User 10112992 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10049143 not in training data
# INFO:src.models.hybrid_recommender:User 10049143 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10168765 not in training data
# INFO:src.models.hybrid_recommender:User 10168765 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10199628 not in training data
# INFO:src.models.hybrid_recommender:User 10199628 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10158147 not in training data
# INFO:src.models.hybrid_recommender:User 10158147 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10179298 not in training data
# INFO:src.models.hybrid_recommender:User 10179298 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10146204 not in training data
# INFO:src.models.hybrid_recommender:User 10146204 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10102294 not in training data
# INFO:src.models.hybrid_recommender:User 10102294 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10103876 not in training data
# INFO:src.models.hybrid_recommender:User 10103876 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10184205 not in training data
# INFO:src.models.hybrid_recommender:User 10184205 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10140235 not in training data
# INFO:src.models.hybrid_recommender:User 10140235 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10020525 not in training data
# INFO:src.models.hybrid_recommender:User 10020525 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10067257 not in training data
# INFO:src.models.hybrid_recommender:User 10067257 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10070963 not in training data
# INFO:src.models.hybrid_recommender:User 10070963 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10135281 not in training data
# INFO:src.models.hybrid_recommender:User 10135281 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10150962 not in training data
# INFO:src.models.hybrid_recommender:User 10150962 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10184085 not in training data
# INFO:src.models.hybrid_recommender:User 10184085 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10139719 not in training data
# INFO:src.models.hybrid_recommender:User 10139719 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10184068 not in training data
# INFO:src.models.hybrid_recommender:User 10184068 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10192283 not in training data
# INFO:src.models.hybrid_recommender:User 10192283 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10048321 not in training data
# INFO:src.models.hybrid_recommender:User 10048321 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10093887 not in training data
# INFO:src.models.hybrid_recommender:User 10093887 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10063275 not in training data
# INFO:src.models.hybrid_recommender:User 10063275 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10146953 not in training data
# INFO:src.models.hybrid_recommender:User 10146953 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10192289 not in training data
# INFO:src.models.hybrid_recommender:User 10192289 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10012357 not in training data
# INFO:src.models.hybrid_recommender:User 10012357 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10172221 not in training data
# INFO:src.models.hybrid_recommender:User 10172221 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10174724 not in training data
# INFO:src.models.hybrid_recommender:User 10174724 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10100956 not in training data
# INFO:src.models.hybrid_recommender:User 10100956 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10009408 not in training data
# INFO:src.models.hybrid_recommender:User 10009408 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10158394 not in training data
# INFO:src.models.hybrid_recommender:User 10158394 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10033226 not in training data
# INFO:src.models.hybrid_recommender:User 10033226 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10153919 not in training data
# INFO:src.models.hybrid_recommender:User 10153919 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10115797 not in training data
# INFO:src.models.hybrid_recommender:User 10115797 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10039394 not in training data
# INFO:src.models.hybrid_recommender:User 10039394 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10124439 not in training data
# INFO:src.models.hybrid_recommender:User 10124439 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10175516 not in training data
# ...
# INFO:src.models.hybrid_recommender:User 10136374 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10158147 not in training data
# INFO:src.models.hybrid_recommender:User 10158147 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10179298 not in training data
# INFO:src.models.hybrid_recommender:User 10179298 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10146204 not in training data
# INFO:src.models.hybrid_recommender:User 10146204 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10102294 not in training data
# INFO:src.models.hybrid_recommender:User 10102294 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10098955 not in training data
# INFO:src.models.hybrid_recommender:User 10098955 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10184281 not in training data
# INFO:src.models.hybrid_recommender:User 10184281 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10205446 not in training data
# INFO:src.models.hybrid_recommender:User 10205446 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10103876 not in training data
# INFO:src.models.hybrid_recommender:User 10103876 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10045901 not in training data
# INFO:src.models.hybrid_recommender:User 10045901 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10127636 not in training data
# INFO:src.models.hybrid_recommender:User 10127636 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10014689 not in training data
# INFO:src.models.hybrid_recommender:User 10014689 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10194852 not in training data
# INFO:src.models.hybrid_recommender:User 10194852 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10184205 not in training data
# INFO:src.models.hybrid_recommender:User 10184205 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10140235 not in training data
# INFO:src.models.hybrid_recommender:User 10140235 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10054837 not in training data
# INFO:src.models.hybrid_recommender:User 10054837 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10020525 not in training data
# INFO:src.models.hybrid_recommender:User 10020525 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10050299 not in training data
# INFO:src.models.hybrid_recommender:User 10050299 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10067257 not in training data
# INFO:src.models.hybrid_recommender:User 10067257 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10070963 not in training data
# INFO:src.models.hybrid_recommender:User 10070963 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10194773 not in training data
# INFO:src.models.hybrid_recommender:User 10194773 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10135281 not in training data
# INFO:src.models.hybrid_recommender:User 10135281 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10150962 not in training data
# INFO:src.models.hybrid_recommender:User 10150962 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10184085 not in training data
# INFO:src.models.hybrid_recommender:User 10184085 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10139719 not in training data
# INFO:src.models.hybrid_recommender:User 10139719 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10184068 not in training data
# INFO:src.models.hybrid_recommender:User 10184068 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10192283 not in training data
# INFO:src.models.hybrid_recommender:User 10192283 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10048321 not in training data
# INFO:src.models.hybrid_recommender:User 10048321 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10126872 not in training data
# INFO:src.models.hybrid_recommender:User 10126872 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10012052 not in training data
# INFO:src.models.hybrid_recommender:User 10012052 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10187168 not in training data
# INFO:src.models.hybrid_recommender:User 10187168 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10179977 not in training data
# INFO:src.models.hybrid_recommender:User 10179977 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10093887 not in training data
# INFO:src.models.hybrid_recommender:User 10093887 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10063275 not in training data
# INFO:src.models.hybrid_recommender:User 10063275 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10076586 not in training data
# INFO:src.models.hybrid_recommender:User 10076586 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10146953 not in training data
# INFO:src.models.hybrid_recommender:User 10146953 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10192289 not in training data
# INFO:src.models.hybrid_recommender:User 10192289 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10126467 not in training data
# INFO:src.models.hybrid_recommender:User 10126467 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10058882 not in training data
# INFO:src.models.hybrid_recommender:User 10058882 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10036497 not in training data
# INFO:src.models.hybrid_recommender:User 10036497 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10012357 not in training data
# INFO:src.models.hybrid_recommender:User 10012357 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10116374 not in training data
# INFO:src.models.hybrid_recommender:User 10116374 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10086445 not in training data
# INFO:src.models.hybrid_recommender:User 10086445 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10172221 not in training data
# INFO:src.models.hybrid_recommender:User 10172221 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10174724 not in training data
# INFO:src.models.hybrid_recommender:User 10174724 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10176245 not in training data
# INFO:src.models.hybrid_recommender:User 10176245 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10100956 not in training data
# INFO:src.models.hybrid_recommender:User 10100956 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10009408 not in training data
# INFO:src.models.hybrid_recommender:User 10009408 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10206471 not in training data
# INFO:src.models.hybrid_recommender:User 10206471 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10158394 not in training data
# INFO:src.models.hybrid_recommender:User 10158394 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10158316 not in training data
# INFO:src.models.hybrid_recommender:User 10158316 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10091990 not in training data
# INFO:src.models.hybrid_recommender:User 10091990 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10186998 not in training data
# INFO:src.models.hybrid_recommender:User 10186998 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10033226 not in training data
# INFO:src.models.hybrid_recommender:User 10033226 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10153919 not in training data
# INFO:src.models.hybrid_recommender:User 10153919 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10032847 not in training data
# INFO:src.models.hybrid_recommender:User 10032847 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10066432 not in training data
# INFO:src.models.hybrid_recommender:User 10066432 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10177115 not in training data
# INFO:src.models.hybrid_recommender:User 10177115 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10149911 not in training data
# INFO:src.models.hybrid_recommender:User 10149911 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10115797 not in training data
# INFO:src.models.hybrid_recommender:User 10115797 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10039394 not in training data
# INFO:src.models.hybrid_recommender:User 10039394 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10010717 not in training data
# INFO:src.models.hybrid_recommender:User 10010717 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10124439 not in training data
# INFO:src.models.hybrid_recommender:User 10124439 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10041180 not in training data
# INFO:src.models.hybrid_recommender:User 10041180 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10128971 not in training data
# INFO:src.models.hybrid_recommender:User 10128971 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10175516 not in training data
# INFO:src.models.hybrid_recommender:User 10175516 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10146802 not in training data
# INFO:src.models.hybrid_recommender:User 10146802 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10071356 not in training data
# INFO:src.models.hybrid_recommender:User 10071356 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10150500 not in training data
# INFO:src.models.hybrid_recommender:User 10150500 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10038664 not in training data
# INFO:src.models.hybrid_recommender:User 10038664 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10128586 not in training data
# INFO:src.models.hybrid_recommender:User 10128586 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10061872 not in training data
# INFO:src.models.hybrid_recommender:User 10061872 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10043488 not in training data
# INFO:src.models.hybrid_recommender:User 10043488 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10157879 not in training data
# INFO:src.models.hybrid_recommender:User 10157879 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10208710 not in training data
# INFO:src.models.hybrid_recommender:User 10208710 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10203550 not in training data
# INFO:src.models.hybrid_recommender:User 10203550 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10095183 not in training data
# INFO:src.models.hybrid_recommender:User 10095183 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10061897 not in training data
# INFO:src.models.hybrid_recommender:User 10061897 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10094485 not in training data
# INFO:src.models.hybrid_recommender:User 10094485 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10151960 not in training data
# INFO:src.models.hybrid_recommender:User 10151960 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10059321 not in training data
# INFO:src.models.hybrid_recommender:User 10059321 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10033578 not in training data
# INFO:src.models.hybrid_recommender:User 10033578 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10187083 not in training data
# INFO:src.models.hybrid_recommender:User 10187083 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10149187 not in training data
# INFO:src.models.hybrid_recommender:User 10149187 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10017465 not in training data
# INFO:src.models.hybrid_recommender:User 10017465 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10183687 not in training data
# INFO:src.models.hybrid_recommender:User 10183687 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10126344 not in training data
# INFO:src.models.hybrid_recommender:User 10126344 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10075380 not in training data
# INFO:src.models.hybrid_recommender:User 10075380 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10082074 not in training data
# INFO:src.models.hybrid_recommender:User 10082074 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10058883 not in training data
# INFO:src.models.hybrid_recommender:User 10058883 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10207126 not in training data
# INFO:src.models.hybrid_recommender:User 10207126 fallback recommendations returned: 10
# WARNING:src.models.collaborative_filtering:User 10201647 not in training data
# INFO:src.models.hybrid_recommender:User 10201647 fallback recommendations returned: 10
#    cold_user_ratio  users_evaluated  user_hit_rate@k  basket_hit_rate@k  \
# 0             0.10             3000         0.362667           0.335667
# 1             0.15             3000         0.355333           0.329667
# 2             0.20             3000         0.353000           0.329000
#
#    served_hit_rate@k  user_precision@k  basket_precision@k  \
# 0           0.362667          0.057033            0.052567
# 1           0.355333          0.055767            0.051600
# 2           0.353000          0.054833            0.051067
#
#    served_precision@k  user_recall@k  basket_recall@k  served_recall@k
# 0            0.057033       0.058846         0.044625         0.058846
# 1            0.055767       0.057030         0.043474         0.057030
# 2            0.054833       0.056038         0.043378         0.056038

# %%
# ====================== CF user-holdout + fallback test ======================
SEED = 42
TEST_USER_RATIO = 0.20
K = 10
MAX_EVAL_USERS = 5000

# 如果训练太慢，先开 True 做快速验证
FAST_MODE = False
TRAIN_USER_CAP = 80000

rng = np.random.RandomState(SEED)

# 1) user-holdout split (natural cold-start)
all_users = implicit_ratings["user_id"].unique()
n_test_users = int(len(all_users) * TEST_USER_RATIO)
test_users = set(rng.choice(all_users, size=n_test_users, replace=False))
train_users = set(all_users) - test_users

train_holdout = implicit_ratings[implicit_ratings["user_id"].isin(train_users)].copy()
test_holdout = implicit_ratings[implicit_ratings["user_id"].isin(test_users)].copy()

print("Train rows:", len(train_holdout), "Test rows:", len(test_holdout))
print("Train users:", train_holdout["user_id"].nunique(), "Test users:", test_holdout["user_id"].nunique())
print("User overlap:", test_holdout["user_id"].isin(train_holdout["user_id"]).mean())  # 期望接近 0

fit_df = train_holdout
if FAST_MODE:
    tr_users = np.array(list(train_users))
    sub_users = set(rng.choice(tr_users, size=min(TRAIN_USER_CAP, len(tr_users)), replace=False))
    fit_df = train_holdout[train_holdout["user_id"].isin(sub_users)].copy()
    print("FAST_MODE on | fit rows:", len(fit_df), "| fit users:", fit_df["user_id"].nunique())

# 2) train CF on holdout-train
cf_holdout = CollaborativeFilteringModel(
    method="als",
    n_factors=48,
    regularization=0.05,
    iterations=10,
    alpha=20.0,
    fallback_on_invalid=False,
)
cf_holdout.fit(fit_df)

# pair-level coverage (你原来那个coverage定义)
m_cf = cf_holdout.evaluate(test_holdout)
print("CF pair-level metrics:", {
    "rmse": m_cf.get("rmse"),
    "mae": m_cf.get("mae"),
    "correlation": m_cf.get("correlation"),
    "coverage": m_cf.get("coverage"),
    "coverage_in_matrix": m_cf.get("coverage_in_matrix"),
    "cold_start_user_rate": m_cf.get("cold_start_user_rate"),
    "cold_start_item_rate": m_cf.get("cold_start_item_rate"),
})

# 3) build popularity fallback list (from train)
popular_items = (
    fit_df.groupby("product_id")
    .size()
    .sort_values(ascending=False)
    .index
    .tolist()
)

def rec_cf_only(user_id, k):
    recs = cf_holdout.get_recommendations(int(user_id), top_n=k, exclude_purchased=True)
    return [int(pid) for pid, _ in recs]

def rec_cf_with_pop_fallback(user_id, k):
    rec_items = rec_cf_only(user_id, k)
    if len(rec_items) > 0:
        return rec_items[:k]
    return popular_items[:k]

def eval_served_metrics(test_df, rec_fn, k=10, max_users=5000, seed=42):
    rng_local = np.random.RandomState(seed)
    user_to_items = test_df.groupby("user_id")["product_id"].apply(set)
    users = np.array(list(user_to_items.index))
    if len(users) > max_users:
        users = rng_local.choice(users, size=max_users, replace=False)

    served = 0
    hits = 0
    precisions = []
    recalls = []

    for u in users:
        gt = user_to_items[u]
        rec_items = rec_fn(u, k)[:k]

        if len(rec_items) > 0:
            served += 1

        if not rec_items:
            precisions.append(0.0)
            recalls.append(0.0)
            continue

        inter = len(set(rec_items) & gt)
        if inter > 0:
            hits += 1
        precisions.append(inter / max(1, k))
        recalls.append(inter / max(1, len(gt)))

    n = len(users)
    return {
        "users_evaluated": int(n),
        "served_coverage": served / n if n else 0.0,  # list-level coverage
        "hit_rate@k": hits / n if n else 0.0,
        "precision@k": float(np.mean(precisions)) if precisions else 0.0,
        "recall@k": float(np.mean(recalls)) if recalls else 0.0,
    }

res_cf_only = eval_served_metrics(test_holdout, rec_cf_only, k=K, max_users=MAX_EVAL_USERS, seed=SEED)
res_cf_fb = eval_served_metrics(test_holdout, rec_cf_with_pop_fallback, k=K, max_users=MAX_EVAL_USERS, seed=SEED)

print("\nCF-only served metrics:", res_cf_only)
print("CF + popular fallback served metrics:", res_cf_fb)
# Out:
# INFO:src.models.collaborative_filtering:Fitting Collaborative Filtering Model (ALS)...
# INFO:src.models.collaborative_filtering:Creating user-item sparse matrix...
# Train rows: 9668502 Test rows: 2415234
# Train users: 129905 Test users: 32476
# User overlap: 0.0
# INFO:src.models.collaborative_filtering:Matrix shape: (129905, 35922)
# INFO:src.models.collaborative_filtering:Sparsity: 99.7928%
# INFO:src.models.collaborative_filtering:Training ALS model...
#   0%|          | 0/10 [00:00<?, ?it/s]
# INFO:src.models.collaborative_filtering:ALS training complete
# INFO:src.models.collaborative_filtering:ALS factor health: user_finite=100.0000% item_finite=100.0000% | user_nonfinite_rows=0.0000% item_nonfinite_rows=0.0000%
# INFO:src.models.collaborative_filtering:ALS check: matrix n_users=129905, n_items=35922 | model.user_factors=129905, model.item_factors=35922
# INFO:src.models.collaborative_filtering:Evaluating model...
# INFO:src.models.collaborative_filtering:Eval diagnostics: cold_start_user_rate=100.00%, cold_start_item_rate=0.00%, in_matrix_rate=0.00%
# INFO:src.models.collaborative_filtering:Eval diagnostics: dropped_empty_items=0
# INFO:src.models.collaborative_filtering:RMSE: nan | MAE: nan | Corr: 0.0000 | coverage(all): 0.00% | coverage(in-matrix): 0.00%
# INFO:src.models.collaborative_filtering:Predict status counts: {} | fallback_rate_in_matrix=0.00%
# CF pair-level metrics: {'rmse': nan, 'mae': nan, 'correlation': 0.0, 'coverage': 0.0, 'coverage_in_matrix': 0.0, 'cold_start_user_rate': 1.0, 'cold_start_item_rate': 0.0}
# WARNING:src.models.collaborative_filtering:User 67534 not in training data
# WARNING:src.models.collaborative_filtering:User 86243 not in training data
# WARNING:src.models.collaborative_filtering:User 154548 not in training data
# WARNING:src.models.collaborative_filtering:User 41552 not in training data
# WARNING:src.models.collaborative_filtering:User 139544 not in training data
# WARNING:src.models.collaborative_filtering:User 19914 not in training data
# WARNING:src.models.collaborative_filtering:User 205673 not in training data
# WARNING:src.models.collaborative_filtering:User 123035 not in training data
# WARNING:src.models.collaborative_filtering:User 36612 not in training data
# WARNING:src.models.collaborative_filtering:User 25494 not in training data
# WARNING:src.models.collaborative_filtering:User 167337 not in training data
# WARNING:src.models.collaborative_filtering:User 127269 not in training data
# WARNING:src.models.collaborative_filtering:User 178658 not in training data
# WARNING:src.models.collaborative_filtering:User 133925 not in training data
# WARNING:src.models.collaborative_filtering:User 59757 not in training data
# WARNING:src.models.collaborative_filtering:User 26936 not in training data
# WARNING:src.models.collaborative_filtering:User 170791 not in training data
# WARNING:src.models.collaborative_filtering:User 25652 not in training data
# WARNING:src.models.collaborative_filtering:User 176848 not in training data
# WARNING:src.models.collaborative_filtering:User 58776 not in training data
# WARNING:src.models.collaborative_filtering:User 8738 not in training data
# WARNING:src.models.collaborative_filtering:User 20892 not in training data
# WARNING:src.models.collaborative_filtering:User 70846 not in training data
# WARNING:src.models.collaborative_filtering:User 149976 not in training data
# WARNING:src.models.collaborative_filtering:User 205299 not in training data
# WARNING:src.models.collaborative_filtering:User 167546 not in training data
# WARNING:src.models.collaborative_filtering:User 36766 not in training data
# WARNING:src.models.collaborative_filtering:User 101528 not in training data
# WARNING:src.models.collaborative_filtering:User 22123 not in training data
# WARNING:src.models.collaborative_filtering:User 76460 not in training data
# WARNING:src.models.collaborative_filtering:User 151346 not in training data
# WARNING:src.models.collaborative_filtering:User 44951 not in training data
# WARNING:src.models.collaborative_filtering:User 133215 not in training data
# WARNING:src.models.collaborative_filtering:User 93343 not in training data
# WARNING:src.models.collaborative_filtering:User 168510 not in training data
# WARNING:src.models.collaborative_filtering:User 122241 not in training data
# WARNING:src.models.collaborative_filtering:User 143649 not in training data
# WARNING:src.models.collaborative_filtering:User 104767 not in training data
# WARNING:src.models.collaborative_filtering:User 175505 not in training data
# WARNING:src.models.collaborative_filtering:User 193559 not in training data
# WARNING:src.models.collaborative_filtering:User 126842 not in training data
# WARNING:src.models.collaborative_filtering:User 106137 not in training data
# WARNING:src.models.collaborative_filtering:User 73946 not in training data
# WARNING:src.models.collaborative_filtering:User 74981 not in training data
# WARNING:src.models.collaborative_filtering:User 76230 not in training data
# WARNING:src.models.collaborative_filtering:User 174229 not in training data
# WARNING:src.models.collaborative_filtering:User 131758 not in training data
# WARNING:src.models.collaborative_filtering:User 59769 not in training data
# WARNING:src.models.collaborative_filtering:User 47230 not in training data
# WARNING:src.models.collaborative_filtering:User 132230 not in training data
# WARNING:src.models.collaborative_filtering:User 43531 not in training data
# WARNING:src.models.collaborative_filtering:User 154412 not in training data
# WARNING:src.models.collaborative_filtering:User 127801 not in training data
# WARNING:src.models.collaborative_filtering:User 201789 not in training data
# WARNING:src.models.collaborative_filtering:User 9338 not in training data
# WARNING:src.models.collaborative_filtering:User 181888 not in training data
# WARNING:src.models.collaborative_filtering:User 145604 not in training data
# WARNING:src.models.collaborative_filtering:User 86028 not in training data
# WARNING:src.models.collaborative_filtering:User 140893 not in training data
# WARNING:src.models.collaborative_filtering:User 205538 not in training data
# WARNING:src.models.collaborative_filtering:User 27528 not in training data
# WARNING:src.models.collaborative_filtering:User 29784 not in training data
# WARNING:src.models.collaborative_filtering:User 50730 not in training data
# WARNING:src.models.collaborative_filtering:User 35373 not in training data
# WARNING:src.models.collaborative_filtering:User 94270 not in training data
# WARNING:src.models.collaborative_filtering:User 169970 not in training data
# WARNING:src.models.collaborative_filtering:User 154595 not in training data
# WARNING:src.models.collaborative_filtering:User 28181 not in training data
# WARNING:src.models.collaborative_filtering:User 100547 not in training data
# WARNING:src.models.collaborative_filtering:User 187843 not in training data
# WARNING:src.models.collaborative_filtering:User 8419 not in training data
# WARNING:src.models.collaborative_filtering:User 111686 not in training data
# WARNING:src.models.collaborative_filtering:User 123137 not in training data
# WARNING:src.models.collaborative_filtering:User 192691 not in training data
# WARNING:src.models.collaborative_filtering:User 94662 not in training data
# WARNING:src.models.collaborative_filtering:User 194157 not in training data
# WARNING:src.models.collaborative_filtering:User 84676 not in training data
# WARNING:src.models.collaborative_filtering:User 8443 not in training data
# WARNING:src.models.collaborative_filtering:User 64946 not in training data
# WARNING:src.models.collaborative_filtering:User 52207 not in training data
# WARNING:src.models.collaborative_filtering:User 173342 not in training data
# WARNING:src.models.collaborative_filtering:User 138292 not in training data
# WARNING:src.models.collaborative_filtering:User 107338 not in training data
# WARNING:src.models.collaborative_filtering:User 156602 not in training data
# WARNING:src.models.collaborative_filtering:User 146636 not in training data
# WARNING:src.models.collaborative_filtering:User 81159 not in training data
# WARNING:src.models.collaborative_filtering:User 13106 not in training data
# WARNING:src.models.collaborative_filtering:User 102862 not in training data
# WARNING:src.models.collaborative_filtering:User 173446 not in training data
# WARNING:src.models.collaborative_filtering:User 44419 not in training data
# WARNING:src.models.collaborative_filtering:User 14042 not in training data
# WARNING:src.models.collaborative_filtering:User 164467 not in training data
# WARNING:src.models.collaborative_filtering:User 117023 not in training data
# WARNING:src.models.collaborative_filtering:User 110815 not in training data
# WARNING:src.models.collaborative_filtering:User 198016 not in training data
# WARNING:src.models.collaborative_filtering:User 93633 not in training data
# WARNING:src.models.collaborative_filtering:User 52183 not in training data
# WARNING:src.models.collaborative_filtering:User 146703 not in training data
# WARNING:src.models.collaborative_filtering:User 82287 not in training data
# WARNING:src.models.collaborative_filtering:User 158167 not in training data
# WARNING:src.models.collaborative_filtering:User 153201 not in training data
# WARNING:src.models.collaborative_filtering:User 186424 not in training data
# WARNING:src.models.collaborative_filtering:User 69923 not in training data
# WARNING:src.models.collaborative_filtering:User 60001 not in training data
# WARNING:src.models.collaborative_filtering:User 30513 not in training data
# WARNING:src.models.collaborative_filtering:User 3644 not in training data
# WARNING:src.models.collaborative_filtering:User 158902 not in training data
# WARNING:src.models.collaborative_filtering:User 82581 not in training data
# WARNING:src.models.collaborative_filtering:User 32721 not in training data
# WARNING:src.models.collaborative_filtering:User 103584 not in training data
# WARNING:src.models.collaborative_filtering:User 81183 not in training data
# WARNING:src.models.collaborative_filtering:User 78815 not in training data
# WARNING:src.models.collaborative_filtering:User 66216 not in training data
# WARNING:src.models.collaborative_filtering:User 117453 not in training data
# WARNING:src.models.collaborative_filtering:User 44416 not in training data
# WARNING:src.models.collaborative_filtering:User 172443 not in training data
# WARNING:src.models.collaborative_filtering:User 191473 not in training data
# WARNING:src.models.collaborative_filtering:User 109852 not in training data
# WARNING:src.models.collaborative_filtering:User 86723 not in training data
# WARNING:src.models.collaborative_filtering:User 134779 not in training data
# WARNING:src.models.collaborative_filtering:User 176455 not in training data
# WARNING:src.models.collaborative_filtering:User 134281 not in training data
# WARNING:src.models.collaborative_filtering:User 77595 not in training data
# WARNING:src.models.collaborative_filtering:User 42076 not in training data
# WARNING:src.models.collaborative_filtering:User 48762 not in training data
# WARNING:src.models.collaborative_filtering:User 197071 not in training data
# WARNING:src.models.collaborative_filtering:User 44132 not in training data
# WARNING:src.models.collaborative_filtering:User 205396 not in training data
# WARNING:src.models.collaborative_filtering:User 29697 not in training data
# WARNING:src.models.collaborative_filtering:User 89394 not in training data
# WARNING:src.models.collaborative_filtering:User 152996 not in training data
# WARNING:src.models.collaborative_filtering:User 105986 not in training data
# WARNING:src.models.collaborative_filtering:User 140147 not in training data
# WARNING:src.models.collaborative_filtering:User 136382 not in training data
# WARNING:src.models.collaborative_filtering:User 201665 not in training data
# WARNING:src.models.collaborative_filtering:User 135004 not in training data
# WARNING:src.models.collaborative_filtering:User 48359 not in training data
# WARNING:src.models.collaborative_filtering:User 103375 not in training data
# WARNING:src.models.collaborative_filtering:User 16210 not in training data
# WARNING:src.models.collaborative_filtering:User 155840 not in training data
# WARNING:src.models.collaborative_filtering:User 20743 not in training data
# WARNING:src.models.collaborative_filtering:User 182145 not in training data
# WARNING:src.models.collaborative_filtering:User 83508 not in training data
# WARNING:src.models.collaborative_filtering:User 122208 not in training data
# WARNING:src.models.collaborative_filtering:User 19712 not in training data
# WARNING:src.models.collaborative_filtering:User 159982 not in training data
# WARNING:src.models.collaborative_filtering:User 194251 not in training data
# WARNING:src.models.collaborative_filtering:User 179253 not in training data
# WARNING:src.models.collaborative_filtering:User 104842 not in training data
# WARNING:src.models.collaborative_filtering:User 102279 not in training data
# WARNING:src.models.collaborative_filtering:User 185024 not in training data
# WARNING:src.models.collaborative_filtering:User 133515 not in training data
# WARNING:src.models.collaborative_filtering:User 143577 not in training data
# WARNING:src.models.collaborative_filtering:User 188154 not in training data
# WARNING:src.models.collaborative_filtering:User 12576 not in training data
# WARNING:src.models.collaborative_filtering:User 173084 not in training data
# WARNING:src.models.collaborative_filtering:User 190740 not in training data
# WARNING:src.models.collaborative_filtering:User 190231 not in training data
# WARNING:src.models.collaborative_filtering:User 136231 not in training data
# WARNING:src.models.collaborative_filtering:User 38351 not in training data
# WARNING:src.models.collaborative_filtering:User 59317 not in training data
# WARNING:src.models.collaborative_filtering:User 84364 not in training data
# WARNING:src.models.collaborative_filtering:User 35970 not in training data
# WARNING:src.models.collaborative_filtering:User 88220 not in training data
# WARNING:src.models.collaborative_filtering:User 149708 not in training data
# WARNING:src.models.collaborative_filtering:User 136222 not in training data
# WARNING:src.models.collaborative_filtering:User 14878 not in training data
# WARNING:src.models.collaborative_filtering:User 34177 not in training data
# WARNING:src.models.collaborative_filtering:User 65482 not in training data
# WARNING:src.models.collaborative_filtering:User 137476 not in training data
# WARNING:src.models.collaborative_filtering:User 116707 not in training data
# WARNING:src.models.collaborative_filtering:User 19943 not in training data
# WARNING:src.models.collaborative_filtering:User 128927 not in training data
# WARNING:src.models.collaborative_filtering:User 119061 not in training data
# WARNING:src.models.collaborative_filtering:User 48011 not in training data
# WARNING:src.models.collaborative_filtering:User 202780 not in training data
# WARNING:src.models.collaborative_filtering:User 133893 not in training data
# WARNING:src.models.collaborative_filtering:User 98024 not in training data
# WARNING:src.models.collaborative_filtering:User 193923 not in training data
# WARNING:src.models.collaborative_filtering:User 35536 not in training data
# WARNING:src.models.collaborative_filtering:User 81229 not in training data
# WARNING:src.models.collaborative_filtering:User 49770 not in training data
# WARNING:src.models.collaborative_filtering:User 124066 not in training data
# WARNING:src.models.collaborative_filtering:User 179948 not in training data
# WARNING:src.models.collaborative_filtering:User 68188 not in training data
# WARNING:src.models.collaborative_filtering:User 90045 not in training data
# WARNING:src.models.collaborative_filtering:User 37773 not in training data
# WARNING:src.models.collaborative_filtering:User 135284 not in training data
# WARNING:src.models.collaborative_filtering:User 96076 not in training data
# WARNING:src.models.collaborative_filtering:User 97501 not in training data
# WARNING:src.models.collaborative_filtering:User 91837 not in training data
# WARNING:src.models.collaborative_filtering:User 186893 not in training data
# WARNING:src.models.collaborative_filtering:User 158960 not in training data
# WARNING:src.models.collaborative_filtering:User 43149 not in training data
# WARNING:src.models.collaborative_filtering:User 77986 not in training data
# WARNING:src.models.collaborative_filtering:User 120166 not in training data
# WARNING:src.models.collaborative_filtering:User 147457 not in training data
# WARNING:src.models.collaborative_filtering:User 199562 not in training data
# WARNING:src.models.collaborative_filtering:User 12060 not in training data
# WARNING:src.models.collaborative_filtering:User 193003 not in training data
# WARNING:src.models.collaborative_filtering:User 42864 not in training data
# WARNING:src.models.collaborative_filtering:User 173294 not in training data
# WARNING:src.models.collaborative_filtering:User 132173 not in training data
# WARNING:src.models.collaborative_filtering:User 32019 not in training data
# WARNING:src.models.collaborative_filtering:User 142269 not in training data
# WARNING:src.models.collaborative_filtering:User 155664 not in training data
# WARNING:src.models.collaborative_filtering:User 175593 not in training data
# WARNING:src.models.collaborative_filtering:User 37382 not in training data
# WARNING:src.models.collaborative_filtering:User 2311 not in training data
# WARNING:src.models.collaborative_filtering:User 133160 not in training data
# WARNING:src.models.collaborative_filtering:User 105517 not in training data
# WARNING:src.models.collaborative_filtering:User 106642 not in training data
# WARNING:src.models.collaborative_filtering:User 24548 not in training data
# WARNING:src.models.collaborative_filtering:User 165410 not in training data
# WARNING:src.models.collaborative_filtering:User 2537 not in training data
# WARNING:src.models.collaborative_filtering:User 22012 not in training data
# WARNING:src.models.collaborative_filtering:User 36669 not in training data
# WARNING:src.models.collaborative_filtering:User 62819 not in training data
# WARNING:src.models.collaborative_filtering:User 63112 not in training data
# WARNING:src.models.collaborative_filtering:User 14595 not in training data
# WARNING:src.models.collaborative_filtering:User 171328 not in training data
# WARNING:src.models.collaborative_filtering:User 194850 not in training data
# WARNING:src.models.collaborative_filtering:User 58194 not in training data
# WARNING:src.models.collaborative_filtering:User 164559 not in training data
# WARNING:src.models.collaborative_filtering:User 137272 not in training data
# WARNING:src.models.collaborative_filtering:User 31654 not in training data
# WARNING:src.models.collaborative_filtering:User 124874 not in training data
# WARNING:src.models.collaborative_filtering:User 112356 not in training data
# WARNING:src.models.collaborative_filtering:User 168936 not in training data
# WARNING:src.models.collaborative_filtering:User 173913 not in training data
# WARNING:src.models.collaborative_filtering:User 2210 not in training data
# WARNING:src.models.collaborative_filtering:User 58697 not in training data
# WARNING:src.models.collaborative_filtering:User 37433 not in training data
# WARNING:src.models.collaborative_filtering:User 143886 not in training data
# WARNING:src.models.collaborative_filtering:User 117817 not in training data
# WARNING:src.models.collaborative_filtering:User 122664 not in training data
# WARNING:src.models.collaborative_filtering:User 151480 not in training data
# WARNING:src.models.collaborative_filtering:User 144344 not in training data
# WARNING:src.models.collaborative_filtering:User 21983 not in training data
# WARNING:src.models.collaborative_filtering:User 105662 not in training data
# WARNING:src.models.collaborative_filtering:User 176666 not in training data
# WARNING:src.models.collaborative_filtering:User 109416 not in training data
# WARNING:src.models.collaborative_filtering:User 539 not in training data
# WARNING:src.models.collaborative_filtering:User 191232 not in training data
# WARNING:src.models.collaborative_filtering:User 201022 not in training data
# WARNING:src.models.collaborative_filtering:User 94880 not in training data
# WARNING:src.models.collaborative_filtering:User 193336 not in training data
# WARNING:src.models.collaborative_filtering:User 174517 not in training data
# WARNING:src.models.collaborative_filtering:User 152939 not in training data
# WARNING:src.models.collaborative_filtering:User 79826 not in training data
# WARNING:src.models.collaborative_filtering:User 67759 not in training data
# WARNING:src.models.collaborative_filtering:User 19970 not in training data
# WARNING:src.models.collaborative_filtering:User 11780 not in training data
# WARNING:src.models.collaborative_filtering:User 71872 not in training data
# WARNING:src.models.collaborative_filtering:User 97401 not in training data
# WARNING:src.models.collaborative_filtering:User 152901 not in training data
# WARNING:src.models.collaborative_filtering:User 177323 not in training data
# WARNING:src.models.collaborative_filtering:User 159029 not in training data
# WARNING:src.models.collaborative_filtering:User 77990 not in training data
# WARNING:src.models.collaborative_filtering:User 112722 not in training data
# WARNING:src.models.collaborative_filtering:User 126917 not in training data
# WARNING:src.models.collaborative_filtering:User 18113 not in training data
# WARNING:src.models.collaborative_filtering:User 71264 not in training data
# WARNING:src.models.collaborative_filtering:User 53088 not in training data
# WARNING:src.models.collaborative_filtering:User 194154 not in training data
# WARNING:src.models.collaborative_filtering:User 142602 not in training data
# WARNING:src.models.collaborative_filtering:User 184018 not in training data
# WARNING:src.models.collaborative_filtering:User 52030 not in training data
# WARNING:src.models.collaborative_filtering:User 131185 not in training data
# WARNING:src.models.collaborative_filtering:User 162229 not in training data
# WARNING:src.models.collaborative_filtering:User 125195 not in training data
# WARNING:src.models.collaborative_filtering:User 130789 not in training data
# WARNING:src.models.collaborative_filtering:User 74088 not in training data
# WARNING:src.models.collaborative_filtering:User 17610 not in training data
# WARNING:src.models.collaborative_filtering:User 5386 not in training data
# WARNING:src.models.collaborative_filtering:User 61898 not in training data
# WARNING:src.models.collaborative_filtering:User 93740 not in training data
# WARNING:src.models.collaborative_filtering:User 3109 not in training data
# WARNING:src.models.collaborative_filtering:User 20389 not in training data
# WARNING:src.models.collaborative_filtering:User 113072 not in training data
# WARNING:src.models.collaborative_filtering:User 182212 not in training data
# WARNING:src.models.collaborative_filtering:User 170103 not in training data
# WARNING:src.models.collaborative_filtering:User 191083 not in training data
# WARNING:src.models.collaborative_filtering:User 66402 not in training data
# WARNING:src.models.collaborative_filtering:User 182717 not in training data
# WARNING:src.models.collaborative_filtering:User 119849 not in training data
# WARNING:src.models.collaborative_filtering:User 63348 not in training data
# WARNING:src.models.collaborative_filtering:User 97432 not in training data
# WARNING:src.models.collaborative_filtering:User 18748 not in training data
# WARNING:src.models.collaborative_filtering:User 31146 not in training data
# WARNING:src.models.collaborative_filtering:User 174129 not in training data
# WARNING:src.models.collaborative_filtering:User 155384 not in training data
# WARNING:src.models.collaborative_filtering:User 39023 not in training data
# WARNING:src.models.collaborative_filtering:User 145190 not in training data
# WARNING:src.models.collaborative_filtering:User 113948 not in training data
# WARNING:src.models.collaborative_filtering:User 197686 not in training data
# WARNING:src.models.collaborative_filtering:User 27967 not in training data
# WARNING:src.models.collaborative_filtering:User 7371 not in training data
# WARNING:src.models.collaborative_filtering:User 198962 not in training data
# WARNING:src.models.collaborative_filtering:User 172236 not in training data
# WARNING:src.models.collaborative_filtering:User 84220 not in training data
# WARNING:src.models.collaborative_filtering:User 129350 not in training data
# WARNING:src.models.collaborative_filtering:User 45374 not in training data
# WARNING:src.models.collaborative_filtering:User 120906 not in training data
# WARNING:src.models.collaborative_filtering:User 66784 not in training data
# WARNING:src.models.collaborative_filtering:User 88081 not in training data
# WARNING:src.models.collaborative_filtering:User 13669 not in training data
# WARNING:src.models.collaborative_filtering:User 5292 not in training data
# WARNING:src.models.collaborative_filtering:User 8346 not in training data
# WARNING:src.models.collaborative_filtering:User 15839 not in training data
# WARNING:src.models.collaborative_filtering:User 151083 not in training data
# WARNING:src.models.collaborative_filtering:User 46675 not in training data
# WARNING:src.models.collaborative_filtering:User 28792 not in training data
# WARNING:src.models.collaborative_filtering:User 125089 not in training data
# WARNING:src.models.collaborative_filtering:User 146835 not in training data
# WARNING:src.models.collaborative_filtering:User 98166 not in training data
# WARNING:src.models.collaborative_filtering:User 49010 not in training data
# WARNING:src.models.collaborative_filtering:User 62377 not in training data
# WARNING:src.models.collaborative_filtering:User 114800 not in training data
# WARNING:src.models.collaborative_filtering:User 75617 not in training data
# WARNING:src.models.collaborative_filtering:User 131348 not in training data
# WARNING:src.models.collaborative_filtering:User 151593 not in training data
# WARNING:src.models.collaborative_filtering:User 67338 not in training data
# WARNING:src.models.collaborative_filtering:User 108297 not in training data
# WARNING:src.models.collaborative_filtering:User 196876 not in training data
# WARNING:src.models.collaborative_filtering:User 165129 not in training data
# WARNING:src.models.collaborative_filtering:User 145223 not in training data
# WARNING:src.models.collaborative_filtering:User 151901 not in training data
# WARNING:src.models.collaborative_filtering:User 167825 not in training data
# WARNING:src.models.collaborative_filtering:User 86568 not in training data
# WARNING:src.models.collaborative_filtering:User 56237 not in training data
# WARNING:src.models.collaborative_filtering:User 123733 not in training data
# WARNING:src.models.collaborative_filtering:User 201641 not in training data
# WARNING:src.models.collaborative_filtering:User 10950 not in training data
# WARNING:src.models.collaborative_filtering:User 176309 not in training data
# WARNING:src.models.collaborative_filtering:User 10055 not in training data
# WARNING:src.models.collaborative_filtering:User 22121 not in training data
# WARNING:src.models.collaborative_filtering:User 164511 not in training data
# WARNING:src.models.collaborative_filtering:User 102701 not in training data
# WARNING:src.models.collaborative_filtering:User 90864 not in training data
# WARNING:src.models.collaborative_filtering:User 56369 not in training data
# WARNING:src.models.collaborative_filtering:User 130051 not in training data
# WARNING:src.models.collaborative_filtering:User 130113 not in training data
# WARNING:src.models.collaborative_filtering:User 156490 not in training data
# WARNING:src.models.collaborative_filtering:User 146992 not in training data
# WARNING:src.models.collaborative_filtering:User 87771 not in training data
# WARNING:src.models.collaborative_filtering:User 71207 not in training data
# WARNING:src.models.collaborative_filtering:User 54125 not in training data
# WARNING:src.models.collaborative_filtering:User 64816 not in training data
# WARNING:src.models.collaborative_filtering:User 168743 not in training data
# WARNING:src.models.collaborative_filtering:User 141617 not in training data
# WARNING:src.models.collaborative_filtering:User 52088 not in training data
# WARNING:src.models.collaborative_filtering:User 26280 not in training data
# WARNING:src.models.collaborative_filtering:User 169901 not in training data
# WARNING:src.models.collaborative_filtering:User 20320 not in training data
# WARNING:src.models.collaborative_filtering:User 9300 not in training data
# WARNING:src.models.collaborative_filtering:User 189459 not in training data
# WARNING:src.models.collaborative_filtering:User 82735 not in training data
# WARNING:src.models.collaborative_filtering:User 146690 not in training data
# WARNING:src.models.collaborative_filtering:User 71889 not in training data
# WARNING:src.models.collaborative_filtering:User 181018 not in training data
# WARNING:src.models.collaborative_filtering:User 48177 not in training data
# WARNING:src.models.collaborative_filtering:User 175802 not in training data
# WARNING:src.models.collaborative_filtering:User 164745 not in training data
# WARNING:src.models.collaborative_filtering:User 17866 not in training data
# WARNING:src.models.collaborative_filtering:User 31883 not in training data
# WARNING:src.models.collaborative_filtering:User 81554 not in training data
# WARNING:src.models.collaborative_filtering:User 125881 not in training data
# WARNING:src.models.collaborative_filtering:User 120369 not in training data
# WARNING:src.models.collaborative_filtering:User 144089 not in training data
# WARNING:src.models.collaborative_filtering:User 8331 not in training data
# WARNING:src.models.collaborative_filtering:User 185955 not in training data
# WARNING:src.models.collaborative_filtering:User 82066 not in training data
# WARNING:src.models.collaborative_filtering:User 97390 not in training data
# WARNING:src.models.collaborative_filtering:User 167590 not in training data
# WARNING:src.models.collaborative_filtering:User 108544 not in training data
# WARNING:src.models.collaborative_filtering:User 168108 not in training data
# WARNING:src.models.collaborative_filtering:User 25590 not in training data
# WARNING:src.models.collaborative_filtering:User 132511 not in training data
# WARNING:src.models.collaborative_filtering:User 174329 not in training data
# WARNING:src.models.collaborative_filtering:User 94563 not in training data
# WARNING:src.models.collaborative_filtering:User 63786 not in training data
# WARNING:src.models.collaborative_filtering:User 60707 not in training data
# WARNING:src.models.collaborative_filtering:User 90350 not in training data
# WARNING:src.models.collaborative_filtering:User 45250 not in training data
# WARNING:src.models.collaborative_filtering:User 57145 not in training data
# WARNING:src.models.collaborative_filtering:User 67096 not in training data
# WARNING:src.models.collaborative_filtering:User 103335 not in training data
# WARNING:src.models.collaborative_filtering:User 98990 not in training data
# WARNING:src.models.collaborative_filtering:User 64659 not in training data
# WARNING:src.models.collaborative_filtering:User 93502 not in training data
# WARNING:src.models.collaborative_filtering:User 68097 not in training data
# WARNING:src.models.collaborative_filtering:User 171804 not in training data
# WARNING:src.models.collaborative_filtering:User 119728 not in training data
# WARNING:src.models.collaborative_filtering:User 101178 not in training data
# WARNING:src.models.collaborative_filtering:User 40150 not in training data
# WARNING:src.models.collaborative_filtering:User 120916 not in training data
# WARNING:src.models.collaborative_filtering:User 118506 not in training data
# WARNING:src.models.collaborative_filtering:User 104510 not in training data
# WARNING:src.models.collaborative_filtering:User 36239 not in training data
# WARNING:src.models.collaborative_filtering:User 152507 not in training data
# WARNING:src.models.collaborative_filtering:User 100178 not in training data
# WARNING:src.models.collaborative_filtering:User 129548 not in training data
# WARNING:src.models.collaborative_filtering:User 73303 not in training data
# WARNING:src.models.collaborative_filtering:User 99922 not in training data
# WARNING:src.models.collaborative_filtering:User 96150 not in training data
# WARNING:src.models.collaborative_filtering:User 99274 not in training data
# WARNING:src.models.collaborative_filtering:User 162881 not in training data
# WARNING:src.models.collaborative_filtering:User 80477 not in training data
# WARNING:src.models.collaborative_filtering:User 98789 not in training data
# WARNING:src.models.collaborative_filtering:User 156604 not in training data
# WARNING:src.models.collaborative_filtering:User 70982 not in training data
# WARNING:src.models.collaborative_filtering:User 194884 not in training data
# WARNING:src.models.collaborative_filtering:User 10020 not in training data
# WARNING:src.models.collaborative_filtering:User 113693 not in training data
# WARNING:src.models.collaborative_filtering:User 185170 not in training data
# WARNING:src.models.collaborative_filtering:User 92205 not in training data
# WARNING:src.models.collaborative_filtering:User 139045 not in training data
# WARNING:src.models.collaborative_filtering:User 184877 not in training data
# WARNING:src.models.collaborative_filtering:User 1306 not in training data
# WARNING:src.models.collaborative_filtering:User 57325 not in training data
# WARNING:src.models.collaborative_filtering:User 193835 not in training data
# WARNING:src.models.collaborative_filtering:User 64480 not in training data
# WARNING:src.models.collaborative_filtering:User 37712 not in training data
# WARNING:src.models.collaborative_filtering:User 130759 not in training data
# WARNING:src.models.collaborative_filtering:User 154123 not in training data
# WARNING:src.models.collaborative_filtering:User 169742 not in training data
# WARNING:src.models.collaborative_filtering:User 105688 not in training data
# WARNING:src.models.collaborative_filtering:User 36388 not in training data
# WARNING:src.models.collaborative_filtering:User 153514 not in training data
# WARNING:src.models.collaborative_filtering:User 143353 not in training data
# WARNING:src.models.collaborative_filtering:User 153957 not in training data
# WARNING:src.models.collaborative_filtering:User 199215 not in training data
# WARNING:src.models.collaborative_filtering:User 28313 not in training data
# WARNING:src.models.collaborative_filtering:User 20037 not in training data
# WARNING:src.models.collaborative_filtering:User 116685 not in training data
# WARNING:src.models.collaborative_filtering:User 202902 not in training data
# WARNING:src.models.collaborative_filtering:User 199316 not in training data
# WARNING:src.models.collaborative_filtering:User 20183 not in training data
# WARNING:src.models.collaborative_filtering:User 68208 not in training data
# WARNING:src.models.collaborative_filtering:User 91127 not in training data
# WARNING:src.models.collaborative_filtering:User 194107 not in training data
# WARNING:src.models.collaborative_filtering:User 73886 not in training data
# WARNING:src.models.collaborative_filtering:User 170660 not in training data
# WARNING:src.models.collaborative_filtering:User 201601 not in training data
# WARNING:src.models.collaborative_filtering:User 181709 not in training data
# WARNING:src.models.collaborative_filtering:User 74195 not in training data
# WARNING:src.models.collaborative_filtering:User 153735 not in training data
# WARNING:src.models.collaborative_filtering:User 69533 not in training data
# WARNING:src.models.collaborative_filtering:User 159239 not in training data
# WARNING:src.models.collaborative_filtering:User 94707 not in training data
# WARNING:src.models.collaborative_filtering:User 158074 not in training data
# WARNING:src.models.collaborative_filtering:User 167390 not in training data
# WARNING:src.models.collaborative_filtering:User 194763 not in training data
# WARNING:src.models.collaborative_filtering:User 56960 not in training data
# WARNING:src.models.collaborative_filtering:User 122413 not in training data
# WARNING:src.models.collaborative_filtering:User 42790 not in training data
# WARNING:src.models.collaborative_filtering:User 91017 not in training data
# WARNING:src.models.collaborative_filtering:User 130218 not in training data
# WARNING:src.models.collaborative_filtering:User 94824 not in training data
# WARNING:src.models.collaborative_filtering:User 51379 not in training data
# WARNING:src.models.collaborative_filtering:User 197277 not in training data
# WARNING:src.models.collaborative_filtering:User 73194 not in training data
# WARNING:src.models.collaborative_filtering:User 99099 not in training data
# WARNING:src.models.collaborative_filtering:User 101069 not in training data
# WARNING:src.models.collaborative_filtering:User 156042 not in training data
# WARNING:src.models.collaborative_filtering:User 169866 not in training data
# WARNING:src.models.collaborative_filtering:User 60974 not in training data
# WARNING:src.models.collaborative_filtering:User 191215 not in training data
# WARNING:src.models.collaborative_filtering:User 1321 not in training data
# WARNING:src.models.collaborative_filtering:User 88329 not in training data
# WARNING:src.models.collaborative_filtering:User 75929 not in training data
# WARNING:src.models.collaborative_filtering:User 90495 not in training data
# WARNING:src.models.collaborative_filtering:User 158941 not in training data
# WARNING:src.models.collaborative_filtering:User 119852 not in training data
# WARNING:src.models.collaborative_filtering:User 14377 not in training data
# WARNING:src.models.collaborative_filtering:User 28341 not in training data
# WARNING:src.models.collaborative_filtering:User 44454 not in training data
# WARNING:src.models.collaborative_filtering:User 157203 not in training data
# WARNING:src.models.collaborative_filtering:User 118447 not in training data
# WARNING:src.models.collaborative_filtering:User 92694 not in training data
# WARNING:src.models.collaborative_filtering:User 63296 not in training data
# WARNING:src.models.collaborative_filtering:User 39169 not in training data
# WARNING:src.models.collaborative_filtering:User 96712 not in training data
# WARNING:src.models.collaborative_filtering:User 176445 not in training data
# WARNING:src.models.collaborative_filtering:User 94032 not in training data
# WARNING:src.models.collaborative_filtering:User 163480 not in training data
# WARNING:src.models.collaborative_filtering:User 176532 not in training data
# WARNING:src.models.collaborative_filtering:User 41781 not in training data
# WARNING:src.models.collaborative_filtering:User 135572 not in training data
# WARNING:src.models.collaborative_filtering:User 34356 not in training data
# WARNING:src.models.collaborative_filtering:User 65867 not in training data
# WARNING:src.models.collaborative_filtering:User 1214 not in training data
# WARNING:src.models.collaborative_filtering:User 87037 not in training data
# WARNING:src.models.collaborative_filtering:User 77070 not in training data
# WARNING:src.models.collaborative_filtering:User 42993 not in training data
# WARNING:src.models.collaborative_filtering:User 188246 not in training data
# WARNING:src.models.collaborative_filtering:User 150677 not in training data
# WARNING:src.models.collaborative_filtering:User 186109 not in training data
# WARNING:src.models.collaborative_filtering:User 40392 not in training data
# WARNING:src.models.collaborative_filtering:User 130926 not in training data
# WARNING:src.models.collaborative_filtering:User 29147 not in training data
# WARNING:src.models.collaborative_filtering:User 9263 not in training data
# WARNING:src.models.collaborative_filtering:User 111020 not in training data
# WARNING:src.models.collaborative_filtering:User 95619 not in training data
# WARNING:src.models.collaborative_filtering:User 178786 not in training data
# WARNING:src.models.collaborative_filtering:User 168986 not in training data
# WARNING:src.models.collaborative_filtering:User 143047 not in training data
# WARNING:src.models.collaborative_filtering:User 25056 not in training data
# WARNING:src.models.collaborative_filtering:User 88069 not in training data
# WARNING:src.models.collaborative_filtering:User 191851 not in training data
# WARNING:src.models.collaborative_filtering:User 11353 not in training data
# WARNING:src.models.collaborative_filtering:User 68325 not in training data
# WARNING:src.models.collaborative_filtering:User 63558 not in training data
# WARNING:src.models.collaborative_filtering:User 14957 not in training data
# WARNING:src.models.collaborative_filtering:User 48877 not in training data
# WARNING:src.models.collaborative_filtering:User 30283 not in training data
# WARNING:src.models.collaborative_filtering:User 92876 not in training data
# WARNING:src.models.collaborative_filtering:User 174040 not in training data
# WARNING:src.models.collaborative_filtering:User 136996 not in training data
# WARNING:src.models.collaborative_filtering:User 174245 not in training data
# WARNING:src.models.collaborative_filtering:User 122418 not in training data
# WARNING:src.models.collaborative_filtering:User 32844 not in training data
# WARNING:src.models.collaborative_filtering:User 15671 not in training data
# WARNING:src.models.collaborative_filtering:User 84837 not in training data
# WARNING:src.models.collaborative_filtering:User 40083 not in training data
# WARNING:src.models.collaborative_filtering:User 19434 not in training data
# WARNING:src.models.collaborative_filtering:User 54126 not in training data
# WARNING:src.models.collaborative_filtering:User 79335 not in training data
# WARNING:src.models.collaborative_filtering:User 98315 not in training data
# WARNING:src.models.collaborative_filtering:User 135206 not in training data
# WARNING:src.models.collaborative_filtering:User 160647 not in training data
# WARNING:src.models.collaborative_filtering:User 180760 not in training data
# WARNING:src.models.collaborative_filtering:User 113442 not in training data
# WARNING:src.models.collaborative_filtering:User 157645 not in training data
# WARNING:src.models.collaborative_filtering:User 152123 not in training data
# WARNING:src.models.collaborative_filtering:User 61495 not in training data
# WARNING:src.models.collaborative_filtering:User 85438 not in training data
# WARNING:src.models.collaborative_filtering:User 46691 not in training data
# WARNING:src.models.collaborative_filtering:User 185582 not in training data
# WARNING:src.models.collaborative_filtering:User 47327 not in training data
# WARNING:src.models.collaborative_filtering:User 140941 not in training data
# WARNING:src.models.collaborative_filtering:User 92925 not in training data
# WARNING:src.models.collaborative_filtering:User 53347 not in training data
# WARNING:src.models.collaborative_filtering:User 135783 not in training data
# WARNING:src.models.collaborative_filtering:User 37337 not in training data
# WARNING:src.models.collaborative_filtering:User 30457 not in training data
# WARNING:src.models.collaborative_filtering:User 76186 not in training data
# WARNING:src.models.collaborative_filtering:User 72075 not in training data
# WARNING:src.models.collaborative_filtering:User 84855 not in training data
# WARNING:src.models.collaborative_filtering:User 100871 not in training data
# WARNING:src.models.collaborative_filtering:User 16403 not in training data
# WARNING:src.models.collaborative_filtering:User 23310 not in training data
# WARNING:src.models.collaborative_filtering:User 51576 not in training data
# WARNING:src.models.collaborative_filtering:User 32035 not in training data
# WARNING:src.models.collaborative_filtering:User 132067 not in training data
# WARNING:src.models.collaborative_filtering:User 52152 not in training data
# WARNING:src.models.collaborative_filtering:User 24409 not in training data
# WARNING:src.models.collaborative_filtering:User 38474 not in training data
# WARNING:src.models.collaborative_filtering:User 179862 not in training data
# WARNING:src.models.collaborative_filtering:User 60731 not in training data
# WARNING:src.models.collaborative_filtering:User 166151 not in training data
# WARNING:src.models.collaborative_filtering:User 189989 not in training data
# WARNING:src.models.collaborative_filtering:User 26505 not in training data
# WARNING:src.models.collaborative_filtering:User 69581 not in training data
# WARNING:src.models.collaborative_filtering:User 32124 not in training data
# WARNING:src.models.collaborative_filtering:User 23951 not in training data
# WARNING:src.models.collaborative_filtering:User 158509 not in training data
# WARNING:src.models.collaborative_filtering:User 164828 not in training data
# WARNING:src.models.collaborative_filtering:User 114868 not in training data
# WARNING:src.models.collaborative_filtering:User 166388 not in training data
# WARNING:src.models.collaborative_filtering:User 92506 not in training data
# WARNING:src.models.collaborative_filtering:User 86074 not in training data
# WARNING:src.models.collaborative_filtering:User 201272 not in training data
# WARNING:src.models.collaborative_filtering:User 53998 not in training data
# WARNING:src.models.collaborative_filtering:User 101097 not in training data
# WARNING:src.models.collaborative_filtering:User 40287 not in training data
# WARNING:src.models.collaborative_filtering:User 167335 not in training data
# WARNING:src.models.collaborative_filtering:User 97124 not in training data
# WARNING:src.models.collaborative_filtering:User 146431 not in training data
# WARNING:src.models.collaborative_filtering:User 192380 not in training data
# WARNING:src.models.collaborative_filtering:User 178430 not in training data
# WARNING:src.models.collaborative_filtering:User 67453 not in training data
# WARNING:src.models.collaborative_filtering:User 86203 not in training data
# WARNING:src.models.collaborative_filtering:User 89176 not in training data
# WARNING:src.models.collaborative_filtering:User 27489 not in training data
# WARNING:src.models.collaborative_filtering:User 2430 not in training data
# WARNING:src.models.collaborative_filtering:User 57768 not in training data
# WARNING:src.models.collaborative_filtering:User 175678 not in training data
# WARNING:src.models.collaborative_filtering:User 19433 not in training data
# WARNING:src.models.collaborative_filtering:User 24568 not in training data
# WARNING:src.models.collaborative_filtering:User 157208 not in training data
# WARNING:src.models.collaborative_filtering:User 135523 not in training data
# WARNING:src.models.collaborative_filtering:User 110519 not in training data
# WARNING:src.models.collaborative_filtering:User 40890 not in training data
# WARNING:src.models.collaborative_filtering:User 194724 not in training data
# WARNING:src.models.collaborative_filtering:User 63892 not in training data
# WARNING:src.models.collaborative_filtering:User 67314 not in training data
# WARNING:src.models.collaborative_filtering:User 51300 not in training data
# WARNING:src.models.collaborative_filtering:User 41038 not in training data
# WARNING:src.models.collaborative_filtering:User 103604 not in training data
# WARNING:src.models.collaborative_filtering:User 36172 not in training data
# WARNING:src.models.collaborative_filtering:User 74483 not in training data
# WARNING:src.models.collaborative_filtering:User 137795 not in training data
# WARNING:src.models.collaborative_filtering:User 105754 not in training data
# WARNING:src.models.collaborative_filtering:User 81877 not in training data
# WARNING:src.models.collaborative_filtering:User 123958 not in training data
# WARNING:src.models.collaborative_filtering:User 199131 not in training data
# WARNING:src.models.collaborative_filtering:User 164953 not in training data
# WARNING:src.models.collaborative_filtering:User 45698 not in training data
# WARNING:src.models.collaborative_filtering:User 18619 not in training data
# WARNING:src.models.collaborative_filtering:User 86689 not in training data
# WARNING:src.models.collaborative_filtering:User 199933 not in training data
# WARNING:src.models.collaborative_filtering:User 127560 not in training data
# WARNING:src.models.collaborative_filtering:User 68288 not in training data
# ...
# WARNING:src.models.collaborative_filtering:User 166 not in training data
# WARNING:src.models.collaborative_filtering:User 52702 not in training data
# WARNING:src.models.collaborative_filtering:User 29198 not in training data
# WARNING:src.models.collaborative_filtering:User 199228 not in training data
# WARNING:src.models.collaborative_filtering:User 72448 not in training data
# WARNING:src.models.collaborative_filtering:User 20628 not in training data
# WARNING:src.models.collaborative_filtering:User 22749 not in training data
# WARNING:src.models.collaborative_filtering:User 79975 not in training data
# WARNING:src.models.collaborative_filtering:User 66555 not in training data
# WARNING:src.models.collaborative_filtering:User 50155 not in training data
# WARNING:src.models.collaborative_filtering:User 43669 not in training data
# WARNING:src.models.collaborative_filtering:User 103924 not in training data
# WARNING:src.models.collaborative_filtering:User 86476 not in training data
# WARNING:src.models.collaborative_filtering:User 126237 not in training data
# WARNING:src.models.collaborative_filtering:User 45911 not in training data
# WARNING:src.models.collaborative_filtering:User 64750 not in training data
# WARNING:src.models.collaborative_filtering:User 55684 not in training data
# WARNING:src.models.collaborative_filtering:User 135354 not in training data
# WARNING:src.models.collaborative_filtering:User 157675 not in training data
# WARNING:src.models.collaborative_filtering:User 127417 not in training data
# WARNING:src.models.collaborative_filtering:User 110497 not in training data
# WARNING:src.models.collaborative_filtering:User 70290 not in training data
# WARNING:src.models.collaborative_filtering:User 164254 not in training data
# WARNING:src.models.collaborative_filtering:User 38181 not in training data
# WARNING:src.models.collaborative_filtering:User 86912 not in training data
# WARNING:src.models.collaborative_filtering:User 121370 not in training data
# WARNING:src.models.collaborative_filtering:User 40006 not in training data
# WARNING:src.models.collaborative_filtering:User 109732 not in training data
# WARNING:src.models.collaborative_filtering:User 201468 not in training data
# WARNING:src.models.collaborative_filtering:User 171484 not in training data
# WARNING:src.models.collaborative_filtering:User 88033 not in training data
# WARNING:src.models.collaborative_filtering:User 3414 not in training data
# WARNING:src.models.collaborative_filtering:User 130446 not in training data
# WARNING:src.models.collaborative_filtering:User 92210 not in training data
# WARNING:src.models.collaborative_filtering:User 24555 not in training data
# WARNING:src.models.collaborative_filtering:User 136010 not in training data
# WARNING:src.models.collaborative_filtering:User 65945 not in training data
# WARNING:src.models.collaborative_filtering:User 47783 not in training data
# WARNING:src.models.collaborative_filtering:User 106462 not in training data
# WARNING:src.models.collaborative_filtering:User 179326 not in training data
# WARNING:src.models.collaborative_filtering:User 76638 not in training data
# WARNING:src.models.collaborative_filtering:User 63573 not in training data
# WARNING:src.models.collaborative_filtering:User 163216 not in training data
# WARNING:src.models.collaborative_filtering:User 54561 not in training data
# WARNING:src.models.collaborative_filtering:User 76192 not in training data
# WARNING:src.models.collaborative_filtering:User 197355 not in training data
# WARNING:src.models.collaborative_filtering:User 6466 not in training data
# WARNING:src.models.collaborative_filtering:User 142363 not in training data
# WARNING:src.models.collaborative_filtering:User 45587 not in training data
# WARNING:src.models.collaborative_filtering:User 180658 not in training data
# WARNING:src.models.collaborative_filtering:User 101891 not in training data
# WARNING:src.models.collaborative_filtering:User 170616 not in training data
# WARNING:src.models.collaborative_filtering:User 37166 not in training data
# WARNING:src.models.collaborative_filtering:User 16853 not in training data
# WARNING:src.models.collaborative_filtering:User 88171 not in training data
# WARNING:src.models.collaborative_filtering:User 182492 not in training data
# WARNING:src.models.collaborative_filtering:User 132960 not in training data
# WARNING:src.models.collaborative_filtering:User 41329 not in training data
# WARNING:src.models.collaborative_filtering:User 79840 not in training data
# WARNING:src.models.collaborative_filtering:User 39282 not in training data
# WARNING:src.models.collaborative_filtering:User 189147 not in training data
# WARNING:src.models.collaborative_filtering:User 168897 not in training data
# WARNING:src.models.collaborative_filtering:User 189064 not in training data
# WARNING:src.models.collaborative_filtering:User 122231 not in training data
# WARNING:src.models.collaborative_filtering:User 18659 not in training data
# WARNING:src.models.collaborative_filtering:User 114702 not in training data
# WARNING:src.models.collaborative_filtering:User 193659 not in training data
# WARNING:src.models.collaborative_filtering:User 76908 not in training data
# WARNING:src.models.collaborative_filtering:User 152986 not in training data
# WARNING:src.models.collaborative_filtering:User 1314 not in training data
# WARNING:src.models.collaborative_filtering:User 187137 not in training data
# WARNING:src.models.collaborative_filtering:User 100253 not in training data
# WARNING:src.models.collaborative_filtering:User 165160 not in training data
# WARNING:src.models.collaborative_filtering:User 116714 not in training data
# WARNING:src.models.collaborative_filtering:User 133775 not in training data
# WARNING:src.models.collaborative_filtering:User 22683 not in training data
# WARNING:src.models.collaborative_filtering:User 193549 not in training data
# WARNING:src.models.collaborative_filtering:User 102152 not in training data
# WARNING:src.models.collaborative_filtering:User 131793 not in training data
# WARNING:src.models.collaborative_filtering:User 124970 not in training data
# WARNING:src.models.collaborative_filtering:User 17356 not in training data
# WARNING:src.models.collaborative_filtering:User 145265 not in training data
# WARNING:src.models.collaborative_filtering:User 120245 not in training data
# WARNING:src.models.collaborative_filtering:User 50289 not in training data
# WARNING:src.models.collaborative_filtering:User 90689 not in training data
# WARNING:src.models.collaborative_filtering:User 170514 not in training data
# WARNING:src.models.collaborative_filtering:User 26952 not in training data
# WARNING:src.models.collaborative_filtering:User 122176 not in training data
# WARNING:src.models.collaborative_filtering:User 87375 not in training data
# WARNING:src.models.collaborative_filtering:User 34322 not in training data
# WARNING:src.models.collaborative_filtering:User 204206 not in training data
# WARNING:src.models.collaborative_filtering:User 184301 not in training data
# WARNING:src.models.collaborative_filtering:User 16205 not in training data
# WARNING:src.models.collaborative_filtering:User 161640 not in training data
# WARNING:src.models.collaborative_filtering:User 73598 not in training data
# WARNING:src.models.collaborative_filtering:User 164046 not in training data
# WARNING:src.models.collaborative_filtering:User 108881 not in training data
# WARNING:src.models.collaborative_filtering:User 86494 not in training data
# WARNING:src.models.collaborative_filtering:User 96155 not in training data
# WARNING:src.models.collaborative_filtering:User 90475 not in training data
# WARNING:src.models.collaborative_filtering:User 16265 not in training data
# WARNING:src.models.collaborative_filtering:User 164357 not in training data
# WARNING:src.models.collaborative_filtering:User 82565 not in training data
# WARNING:src.models.collaborative_filtering:User 141859 not in training data
# WARNING:src.models.collaborative_filtering:User 86951 not in training data
# WARNING:src.models.collaborative_filtering:User 68837 not in training data
# WARNING:src.models.collaborative_filtering:User 165109 not in training data
# WARNING:src.models.collaborative_filtering:User 105887 not in training data
# WARNING:src.models.collaborative_filtering:User 135856 not in training data
# WARNING:src.models.collaborative_filtering:User 158197 not in training data
# WARNING:src.models.collaborative_filtering:User 52791 not in training data
# WARNING:src.models.collaborative_filtering:User 137660 not in training data
# WARNING:src.models.collaborative_filtering:User 52140 not in training data
# WARNING:src.models.collaborative_filtering:User 11388 not in training data
# WARNING:src.models.collaborative_filtering:User 192278 not in training data
# WARNING:src.models.collaborative_filtering:User 126474 not in training data
# WARNING:src.models.collaborative_filtering:User 75775 not in training data
# WARNING:src.models.collaborative_filtering:User 36555 not in training data
# WARNING:src.models.collaborative_filtering:User 103269 not in training data
# WARNING:src.models.collaborative_filtering:User 88342 not in training data
# WARNING:src.models.collaborative_filtering:User 153796 not in training data
# WARNING:src.models.collaborative_filtering:User 17008 not in training data
# WARNING:src.models.collaborative_filtering:User 183697 not in training data
# WARNING:src.models.collaborative_filtering:User 167735 not in training data
# WARNING:src.models.collaborative_filtering:User 31065 not in training data
# WARNING:src.models.collaborative_filtering:User 33661 not in training data
# WARNING:src.models.collaborative_filtering:User 39552 not in training data
# WARNING:src.models.collaborative_filtering:User 117326 not in training data
# WARNING:src.models.collaborative_filtering:User 110007 not in training data
# WARNING:src.models.collaborative_filtering:User 25794 not in training data
# WARNING:src.models.collaborative_filtering:User 107866 not in training data
# WARNING:src.models.collaborative_filtering:User 147923 not in training data
# WARNING:src.models.collaborative_filtering:User 39983 not in training data
# WARNING:src.models.collaborative_filtering:User 48997 not in training data
# WARNING:src.models.collaborative_filtering:User 17622 not in training data
# WARNING:src.models.collaborative_filtering:User 67263 not in training data
# WARNING:src.models.collaborative_filtering:User 72690 not in training data
# WARNING:src.models.collaborative_filtering:User 137808 not in training data
# WARNING:src.models.collaborative_filtering:User 102215 not in training data
# WARNING:src.models.collaborative_filtering:User 134614 not in training data
# WARNING:src.models.collaborative_filtering:User 85092 not in training data
# WARNING:src.models.collaborative_filtering:User 55515 not in training data
# WARNING:src.models.collaborative_filtering:User 20694 not in training data
# WARNING:src.models.collaborative_filtering:User 144241 not in training data
# WARNING:src.models.collaborative_filtering:User 51655 not in training data
# WARNING:src.models.collaborative_filtering:User 52014 not in training data
# WARNING:src.models.collaborative_filtering:User 92588 not in training data
# WARNING:src.models.collaborative_filtering:User 72895 not in training data
# WARNING:src.models.collaborative_filtering:User 80802 not in training data
# WARNING:src.models.collaborative_filtering:User 16997 not in training data
# WARNING:src.models.collaborative_filtering:User 17925 not in training data
# WARNING:src.models.collaborative_filtering:User 75501 not in training data
# WARNING:src.models.collaborative_filtering:User 92257 not in training data
# WARNING:src.models.collaborative_filtering:User 36881 not in training data
# WARNING:src.models.collaborative_filtering:User 202990 not in training data
# WARNING:src.models.collaborative_filtering:User 177679 not in training data
# WARNING:src.models.collaborative_filtering:User 163574 not in training data
# WARNING:src.models.collaborative_filtering:User 21668 not in training data
# WARNING:src.models.collaborative_filtering:User 172460 not in training data
# WARNING:src.models.collaborative_filtering:User 73906 not in training data
# WARNING:src.models.collaborative_filtering:User 134892 not in training data
# WARNING:src.models.collaborative_filtering:User 14114 not in training data
# WARNING:src.models.collaborative_filtering:User 176953 not in training data
# WARNING:src.models.collaborative_filtering:User 119069 not in training data
# WARNING:src.models.collaborative_filtering:User 183879 not in training data
# WARNING:src.models.collaborative_filtering:User 202393 not in training data
# WARNING:src.models.collaborative_filtering:User 103647 not in training data
# WARNING:src.models.collaborative_filtering:User 30717 not in training data
# WARNING:src.models.collaborative_filtering:User 75650 not in training data
# WARNING:src.models.collaborative_filtering:User 45670 not in training data
# WARNING:src.models.collaborative_filtering:User 173824 not in training data
# WARNING:src.models.collaborative_filtering:User 140530 not in training data
# WARNING:src.models.collaborative_filtering:User 118464 not in training data
# WARNING:src.models.collaborative_filtering:User 201339 not in training data
# WARNING:src.models.collaborative_filtering:User 186349 not in training data
# WARNING:src.models.collaborative_filtering:User 50794 not in training data
# WARNING:src.models.collaborative_filtering:User 181003 not in training data
# WARNING:src.models.collaborative_filtering:User 67408 not in training data
# WARNING:src.models.collaborative_filtering:User 203412 not in training data
# WARNING:src.models.collaborative_filtering:User 161962 not in training data
# WARNING:src.models.collaborative_filtering:User 95245 not in training data
# WARNING:src.models.collaborative_filtering:User 176327 not in training data
# WARNING:src.models.collaborative_filtering:User 169185 not in training data
# WARNING:src.models.collaborative_filtering:User 194781 not in training data
# WARNING:src.models.collaborative_filtering:User 94684 not in training data
# WARNING:src.models.collaborative_filtering:User 167732 not in training data
# WARNING:src.models.collaborative_filtering:User 165131 not in training data
# WARNING:src.models.collaborative_filtering:User 196099 not in training data
# WARNING:src.models.collaborative_filtering:User 81844 not in training data
# WARNING:src.models.collaborative_filtering:User 35367 not in training data
# WARNING:src.models.collaborative_filtering:User 16980 not in training data
# WARNING:src.models.collaborative_filtering:User 90908 not in training data
# WARNING:src.models.collaborative_filtering:User 182010 not in training data
# WARNING:src.models.collaborative_filtering:User 189116 not in training data
# WARNING:src.models.collaborative_filtering:User 136638 not in training data
# WARNING:src.models.collaborative_filtering:User 115402 not in training data
# WARNING:src.models.collaborative_filtering:User 35587 not in training data
# WARNING:src.models.collaborative_filtering:User 87226 not in training data
# WARNING:src.models.collaborative_filtering:User 117919 not in training data
# WARNING:src.models.collaborative_filtering:User 202082 not in training data
# WARNING:src.models.collaborative_filtering:User 125362 not in training data
# WARNING:src.models.collaborative_filtering:User 123391 not in training data
# WARNING:src.models.collaborative_filtering:User 99763 not in training data
# WARNING:src.models.collaborative_filtering:User 1795 not in training data
# WARNING:src.models.collaborative_filtering:User 171273 not in training data
# WARNING:src.models.collaborative_filtering:User 179162 not in training data
# WARNING:src.models.collaborative_filtering:User 13599 not in training data
# WARNING:src.models.collaborative_filtering:User 41735 not in training data
# CF-only served metrics: {'users_evaluated': 5000, 'served_coverage': 0.0, 'hit_rate@k': 0.0, 'precision@k': 0.0, 'recall@k': 0.0}
# CF + popular fallback served metrics: {'users_evaluated': 5000, 'served_coverage': 1.0, 'hit_rate@k': 0.8482, 'precision@k': 0.2815, 'recall@k': 0.04633050686068931}
